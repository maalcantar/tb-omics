# %%
#OUTSTANDING ISSUES: THERE ARE DUPLICATE METABOLITES LOL 
import random
import numpy as np
import scipy as sp
import collections
import pandas as pd
from pylab import *
import seaborn as sns
import os
from matplotlib import pyplot as plt
from IPython.display import clear_output
import statsmodels.stats.multitest as multi
import sys
import warnings

from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import average_precision_score

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    warnings.filterwarnings("ignore", category=UserWarning)

sns.set_style('white')
pd.options.display.float_format = '{:,.7f}'.format
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1500)

#set for reproducibility
#check current working directory

if (os.getcwd().split('\\')[-1] != 'data'):
    os.chdir('./data')
print(os.getcwd())
# Out:
# /Users/calgunnarsson/tb-omics/data

# %%
def load_metabolomics(filename):
    # loading in TB plasma metabolomics data from tab-delimted file to pandas dataframe
    df = pd.read_csv(filename)
    df = df.rename(columns={df.columns.values[0]: 'metabolite_name'})
    df = df.transpose()
    df.columns = df.iloc[0, :]
    df = df.iloc[1:, :]
    df.index.name = 'sample_id'
    
    return df

# %%
def impute(df, thresh=0.1):
    #retain columns with proportion missing values < threshold
    df = df[df.columns[df.isnull().mean() < thresh]]
    #impute remaining nans with minimum value
    df = df.apply(lambda x: x.fillna(x.min()), axis=0)
    return df.dropna(axis=1)

# %%
def load_patientmetadata(filename):
    # reading in patient metadata
    p_df = pd.read_csv(filename)
    p_df.columns = p_df.columns.str.lower().str.rstrip()
    p_df = p_df.set_index('sample_id') 
    #drop redundant columns
    p_df = p_df.drop(columns=[p_df.columns.values[0], 'id'])
    
    return p_df

def load_biochemicaldata(filename):
    b_df = pd.read_csv(filename)
    b_df.columns = b_df.columns.str.lower()
    b_df = b_df.set_index('id')
    b_df = b_df.drop(columns=[b_df.columns.values[0]])
    
    return b_df.reset_index()

def combine_data(p_df, m_df, b_df):
    #join with full dataset
    m_df = m_df.set_index('sample_id').join(p_df)
    #rename columns with biologically meaningful metabolite names
    b_dict = dict(zip(b_df['id'], b_df['biochemical']))
    m_df = m_df.rename(b_dict, axis='columns')
    m_df = m_df.reset_index()
    #consolidate duplicated metabolites as maximum value across duplicates
    m_df_nodup = m_df.loc[:, ~m_df.columns.duplicated()]
    for dup in m_df.columns[m_df.columns.duplicated()].unique():
        temp = m_df[dup]
        m_df_nodup[dup] = temp.max(axis=1)
    #remove unindentified metabs    
    m_df_nodup = m_df_nodup.loc[:, ~m_df_nodup.columns.str.startswith('X -')]
    return m_df_nodup

# %%
# 
def standardize_data(f_vals):
    from sklearn import preprocessing

    # applying standardization 
    scaler = preprocessing.QuantileTransformer()#StandardScaler()
    data_scaled = scaler.fit_transform(f_vals)
    
    return data_scaled

# %%
def make_df(f_vals, features, l_vals, labels):
    df = pd.concat([pd.DataFrame(data=l_vals, columns=labels), 
                    pd.DataFrame(data=f_vals, columns=features)], axis=1)
    return df

# %%
def perform_PCA(data, l_vals, labels, save=False, ncomp=10):
# computing principal components
    from sklearn import decomposition

    pcaAbs = decomposition.PCA(n_components=ncomp)
    data_PCA = pcaAbs.fit_transform(data)
    
    pc_cols = ['PC ' + str(i) for i in np.arange(1, ncomp + 1)]
    df_PCA = make_df(data_PCA, pc_cols, l_vals, labels)
    
    #Plot explained variance by number of components
    var_exp = pcaAbs.explained_variance_ratio_
    fig_ve, ax_ve = plt.subplots(1, 1)
    sns.lineplot(x=(np.arange(len(var_exp)) + 1), y=np.cumsum(var_exp), ax=ax_ve)
    plt.xlabel('PCA component number')
    plt.ylabel('Cumulative variance ratio')
    if save:
        plt.savefig('variance-exp.png', bbox_inches='tight', pad_inches=0.5)
    
    fig_pca, ax_pca = plt.subplots(1, 1)
    sns.scatterplot(x='PC 1', y='PC 2', data=df_PCA, hue='group', ax=ax_pca)
    
    return df_PCA

# %%
#calculate p-value on continuous data, selecting appropriate test based on normality & equal variance tests
def significanceTest(ctrl, case, alpha_normal=0.05):
    try:
        _, p_normal_ctrl = sp.stats.normaltest(ctrl, nan_policy='omit')
        _, p_normal_case = sp.stats.normaltest(case, nan_policy='omit')
    except:
        p_normal_ctrl = 1 
        p_normal_case = 1
        
    if (np.any(p_normal_ctrl < alpha_normal) and np.any(p_normal_case < alpha_normal)):
        _, p_var = sp.stats.bartlett(ctrl, case)
        stat, p_diff = sp.stats.ttest_ind(ctrl, case, nan_policy='omit', equal_var=(p_var < alpha_normal))
    else:
        stat, p_diff = sp.stats.ranksums(ctrl, case)
    
    return stat, p_diff

# %%
def significantMetabolites(ctrl, case, features, labels, alpha_normal=0.05, alpha_diff=0.05):
    pvals = []
    logfc = []
    stats = []
    for metab in features:
        metab_ctrl = ctrl[metab].values 
        metab_case = case[metab].values
        if (len(metab_ctrl.shape) > 1):
            display(metab)
        stat, p_diff = significanceTest(metab_ctrl, metab_case, alpha_normal=alpha_normal)
        pvals.append(p_diff)
        stats.append(stat)
        fc = np.mean(metab_case) / np.mean(metab_ctrl) #not matched in any way
        logfc.append(np.log2(fc))
    padj = multi.multipletests(pvals, alpha=alpha_diff, method='fdr_bh')
    
    significant = pd.DataFrame({'metabolite' : features, 'logFC' : logfc,
                                'statistic' : stats, 'P.Value' :  pvals, 'q' : padj[1]})
    
    return significant.sort_values(by='P.Value')

# %%
def convertHMDB(metabs, b_df):
    hmdb_dict = dict(zip(b_df['biochemical'], b_df['hmdb']))
    hmdb_ids  = [hmdb_dict[metab] for metab in metabs]
    return hmdb_ids

# %%
all_files = ['measurements_plasma_full.csv', 'measurements_serum_full.csv', 'measurements_plasmarpmi_full.csv']
all_df = []
for file in all_files:
    temp_df = impute(load_metabolomics(file))
    index = temp_df.index
    temp_df = pd.DataFrame(data=standardize_data(temp_df), columns=temp_df.columns)
    temp_df.index = index
    all_df.append(temp_df)
    
full_df   = pd.concat(all_df, sort=False).reset_index()
patient_df = load_patientmetadata('full_unblinded_metadata_with_smoking_tst.csv')
chem_df = load_biochemicaldata('biochemicals_full_list_5.csv')
full_df = combine_data(patient_df, full_df, chem_df)
full_df.to_csv('standardized_TB_metabolomes.csv')

labels = list(patient_df)
features = [x for x in list(full_df.columns) if x not in labels]
f_vals = full_df.loc[:, features].values
l_vals = full_df.loc[:, labels].values

# displaying shape and first few data entries
print('The shape of our data matrix is: ', full_df.shape)
# Out:
# The shape of our data matrix is:  (751, 875)

# %%
full_df.head()#['hydroxy-CMPF*']
# Out:
#     sample_id  1,2-propanediol  1,3,7-trimethylurate  1,3-dimethylurate  \
# 0  MPIIB.9274        0.0850779             0.7784280          0.9208654
# 1  MPIIB.8120        0.2983645             0.8270947          0.6276167
# 2  MPIIB.4027        0.3064539             0.0000001          0.0000001
# 3  MPIIB.8316        0.9178979             0.5916339          0.5999295
# 4  MPIIB.8823        0.0906865             0.9040755          0.9288215
#
#    1,5-anhydroglucitol (1,5-AG)  1,6-anhydroglucose  1,7-dimethylurate  \
# 0                     0.1511030           0.0000001          0.8658478
# 1                     0.8931677           0.4848066          0.6114713
# 2                     0.3233153           0.8768465          0.3695462
# 3                     0.5229708           0.0000001          0.5921507
# 4                     0.7712713           0.9729611          0.9011234
#
#    10-heptadecenoate (17:1n7)  10-nonadecenoate (19:1n9)  \
# 0                   0.7701044                  0.9785029
# 1                   0.4302366                  0.5397896
# 2                   0.3862419                  0.6186412
# 3                   0.4792112                  0.4297704
# 4                   0.9589284                  0.9479468
#
#    10-undecenoate (11:1n1)  11-dehydrocorticosterone  12,13-DiHOME  \
# 0                0.7782222                 0.8379086     0.8467409
# 1                0.5889866                 0.0000001     0.1891670
# 2                0.2930573                 0.6626627     0.6767016
# 3                0.1395275                 0.0000001     0.3424125
# 4                0.6333698                 0.0000001     0.7205716
#
#    13-HODE + 9-HODE  15-methylpalmitate (i17:0)  16a-hydroxy DHEA 3-sulfate  \
# 0         0.8328335                   0.0000001                   0.9890161
# 1         0.0654671                   0.5617332                   0.3811434
# 2         0.0932524                   0.3834934                   0.3645142
# 3         0.2325334                   0.3891555                   0.4435467
# 4         0.9837183                   0.9068919                   0.2439485
#
#    16-hydroxypalmitate  17-methylstearate (i19:0)  \
# 0            0.9016477                  0.9124416
# 1            0.3478668                  0.6466097
# 2            0.2658208                  0.3842266
# 3            0.1755881                  0.6108595
# 4            0.8901011                  0.9284645
#
#    1-arachidonoyl-GPC (20:4n6)*  1-arachidonoyl-GPE (20:4n6)*  \
# 0                     0.5401559                     0.5835341
# 1                     0.0463307                     0.6083847
# 2                     0.0220128                     0.1466466
# 3                     0.3563257                     0.0794598
# 4                     0.0190683                     0.2465281
#
#    1-arachidonoyl-GPI (20:4)*  1-arachidonoyl-GPA (20:4)  \
# 0                   0.5339370                  0.5315030
# 1                   0.2412208                  0.1451539
# 2                   0.1451862                  0.1206820
# 3                   0.3204942                  0.3316491
# 4                   0.4384336                  0.9725953
#
#    1-arachidonylglycerol (20:4)  1-arachidoyl-GPC (20:0)  \
# 0                     0.8459904                0.4437557
# 1                     0.0000001                0.0628440
# 2                     0.1461037                0.0549201
# 3                     0.2576096                0.0847817
# 4                     0.6679194                0.5725969
#
#    1-dihomo-linoleoyl-GPC (20:2)*  1-docosahexaenoylglycerol (22:6)  \
# 0                       0.8111705                         0.5832738
# 1                       0.1259037                         0.2990457
# 2                       0.1233311                         0.4847555
# 3                       0.1311806                         0.4104261
# 4                       0.2631937                         0.6634343
#
#    1-docosahexaenoyl-GPC (22:6)*  1-docosahexaenoyl-GPE (22:6)*  \
# 0                      0.2845626                      0.5344477
# 1                      0.0328620                      0.5232302
# 2                      0.0711022                      0.4485161
# 3                      0.2251157                      0.2409981
# 4                      0.0983291                      0.5532657
#
#    1-docosapentaenoyl-GPC (22:5n3)*  1-docosapentaenoyl-GPC (22:5n6)*  \
# 0                         0.1181060                         0.6931143
# 1                         0.0303013                         0.6714153
# 2                         0.0469014                         0.1233690
# 3                         0.2851245                         0.5070823
# 4                         0.1996441                         0.0907466
#
#    1-eicosapentaenoyl-GPC (20:5)*  1-eicosapentaenoyl-GPE (20:5)*  \
# 0                       0.0160367                       0.0000001
# 1                       0.0796956                       0.3150558
# 2                       0.0199272                       0.0000001
# 3                       0.2439459                       0.3291208
# 4                       0.3782821                       0.2985782
#
#    1-dihomo-linolenoyl-GPC (20:3n3 or 6)*  \
# 0                               0.5585624
# 1                               0.0933088
# 2                               0.0081561
# 3                               0.3370051
# 4                               0.0328055
#
#    1-dihomo-linolenoyl-GPE (20:3n3 or 6)*  1-eicosenoyl-GPC (20:1)*  \
# 0                               0.7750943                 0.4054455
# 1                               0.7016171                 0.0466963
# 2                               0.1863496                 0.1069734
# 3                               0.3292592                 0.0762905
# 4                               0.5344247                 0.4771605
#
#    1-linolenoylglycerol (18:3)  1-linolenoyl-GPC (18:3)*  \
# 0                    0.3397020                 0.1838641
# 1                    0.3452962                 0.1173038
# 2                    0.4987122                 0.1150521
# 3                    0.5616045                 0.1725157
# 4                    0.8166524                 0.1620465
#
#    1-linoleoylglycerol (18:2)  1-linoleoyl-GPC (18:2)  \
# 0                   0.7588480               0.7588823
# 1                   0.3554639               0.1585986
# 2                   0.3425345               0.1671009
# 3                   0.5095762               0.2359560
# 4                   0.8599825               0.0761105
#
#    1-linoleoyl-GPE (18:2)*  1-linoleoyl-GPI (18:2)*  1-margaroyl-GPC (17:0)  \
# 0                0.7889304                0.8658167               0.3643652
# 1                0.4384280                0.2411449               0.0353154
# 2                0.3701754                0.2277719               0.0469922
# 3                0.3180376                0.1671608               0.2817595
# 4                0.1840902                0.4003378               0.6600486
#
#    1-margaroyl-GPE (17:0)*  N-methylpipecolate  1-methylhistidine  \
# 0                0.5532249           0.2467031          0.2602676
# 1                0.5727072           0.7287590          0.6137156
# 2                0.4546707           0.0520593          0.0491968
# 3                0.6029255           0.1122633          0.0540926
# 4                0.9043469           0.8568967          0.5478944
#
#    1-methylnicotinamide  1-methylurate  1-methylxanthine  \
# 0             0.0000001      0.8928999         0.8823314
# 1             0.8387874      0.7073542         0.5233932
# 2             0.0000001      0.5425159         0.2794003
# 3             0.0000001      0.8244437         0.7425132
# 4             0.0000001      0.8828224         0.9310139
#
#    1-myristoylglycerol (14:0)  1-myristoyl-GPC (14:0)  \
# 0                   0.2275084               0.4765270
# 1                   0.5453968               0.0821049
# 2                   0.2492833               0.0438701
# 3                   0.2874592               0.2170725
# 4                   0.8850224               0.4824773
#
# 4       0.8819410        0.2822033          0.5477128         0.4929433
#
#    2-aminophenol sulfate  2-arachidonoyl-GPC (20:4)*  \
# 0              0.6876654                   0.3643717
# 1              0.7781281                   0.0272780
# 2              0.8900664                   0.0933651
# 3              0.7372549                   0.5261941
# 4              0.9043117                   0.0138813
#
#    2-arachidonoyl-GPE (20:4)*  2'-deoxyuridine  2-docosahexaenoyl-GPC (22:6)*  \
# 0                   0.5175569        0.3591960                      0.4165266
# 1                   0.0712773        0.3262648                      0.0137828
# 2                   0.1210206        0.8354162                      0.3065899
# 3                   0.4713544        0.6960591                      0.3042709
# 4                   0.0220159        0.1972301                      0.1454281
#
#    2-docosahexaenoyl-GPE (22:6)*  2-docosapentaenoyl-GPC (22:5n3)*  \
# 0                      0.7009297                         0.1453529
# 1                      0.4957252                         0.0411609
# 2                      0.2904403                         0.1172877
# 3                      0.4522580                         0.6575630
# 4                      0.5785561                         0.1642841
#
#    2-dihomo-linolenoyl-GPC (20:3n3 or 6)*  2-ethylhexanoate  \
# 0                               0.5453262         0.9753136
# 1                               0.1807101         0.8900845
# 2                               0.0192241         0.8600873
# 3                               0.5207518         0.5230265
# 4                               0.0601656         0.9641882
#
#    2-ethylphenylsulfate  2-hydroxy-3-methylvalerate  \
# 0             0.0000001                   0.6961256
# 1             0.3863529                   0.8796542
# 2             0.8713160                   0.7069634
# 3             0.5398964                   0.7836221
# 4             0.8768340                   0.8303557
#
#    2-hydroxyacetaminophen sulfate*  2-hydroxybutyrate (AHB)  \
# 0                        0.0000001                0.8599261
# 1                        0.0000001                0.7536280
# 2                        0.0000001                0.1011032
# 3                        0.0000001                0.1865949
# 4                        0.0000001                0.7865961
#
#    2-hydroxydecanoate  2-hydroxyglutarate  2-hydroxyhippurate (salicylurate)  \
# 0           0.3973238           0.1915251                          0.0000001
# 1           0.8628928           0.1235639                          0.8188221
# 2           0.4054111           0.0830551                          0.5098557
# 3           0.5041923           0.0873628                          0.4956316
# 4           0.4630396           0.7011897                          0.0000001
#
#    2-hydroxyisobutyrate  2-hydroxyoctanoate  2-hydroxypalmitate  \
# 0             0.3373202           0.0381736           0.5152143
# 1             0.6646647           0.1671590           0.3232877
# 2             0.1891470           0.3573574           0.3041096
# 3             0.3588748           0.0273702           0.3999789
# 4             0.5257668           0.8411333           0.9261577
#
#    2-hydroxystearate  2-linolenoyl-GPC (18:3)*  2-linoleoylglycerol (18:2)  \
# 0          0.1836669                 0.3396673                   0.6736939
# 1          0.4326463                 0.2990220                   0.7067933
# 2          0.2242386                 0.3039122                   0.1509117
# 3          0.1726318                 0.3313428                   0.5558860
# 4          0.9508663                 0.3095786                   0.7150489
#
#    2-linoleoyl-GPC (18:2)*  2-linoleoyl-GPE (18:2)*  2-margaroyl-GPC (17:0)*  \
# 0                0.8412800                0.6304363                0.7039751
# 1                0.2250844                0.5667137                0.1619271
# 2                0.2736405                0.2992695                0.1259299
# 3                0.4246510                0.2738290                0.5917522
# 4                0.1144112                0.6396396                0.7071464
#
#    2-methylbutyrylcarnitine (C5)  2-methylmalonylcarnitine (C4-DC)  \
#
#    cotinine N-oxide  creatine  creatinine  cyclo(gly-pro)  cyclo(leu-pro)  \
# 0         0.0000001 0.7698837   0.2956065       0.3533601       0.4030259
# 1         0.0000001 0.9756807   0.1260200       0.4875479       0.3916897
# 2         0.0000001 0.3509461   0.2738107       0.3342186       0.1291236
# 3         0.0000001 0.5616331   0.0712558       0.2521971       0.1150509
# 4         0.0000001 0.7287745   0.0670671       0.9588928       0.9670383
#
#    cyclo(phe-pro)  cys-gly, oxidized  cysteine  \
# 0       0.6518948          0.8874736 0.7617357
# 1       0.4714352          0.6946947 0.6824584
# 2       0.2988932          0.6246487 0.2549560
# 3       0.2492880          0.7070861 0.6384188
# 4       0.9369523          0.0000001 0.0468829
#
#    cysteine-glutathione disulfide   cystine  cytidine  \
# 0                       0.6927466 0.4848413 0.8492669
# 1                       0.7527708 0.7969248 0.7426423
# 2                       0.8462991 0.5122876 0.6246263
# 3                       0.6031358 0.5727158 0.4740569
# 4                       0.0000001 0.0000001 0.2438758
#
#    decanoylcarnitine (C10)  dehydroisoandrosterone sulfate (DHEA-S)  \
# 0                0.7725551                                0.9780514
# 1                0.3321418                                0.7670679
# 2                0.4136610                                0.2688938
# 3                0.1201628                                0.3592823
# 4                0.0990297                                0.1891564
#
#    deoxycarnitine  dihomo-linoleate (20:2n6)  \
# 0       0.3726243                  0.9808338
# 1       0.2022184                  0.3892501
# 2       0.6110246                  0.5781611
# 3       0.3944674                  0.3753211
# 4       0.0439940                  0.9618717
#
#    dihomo-linolenate (20:3n3 or n6)  dimethyl sulfone  \
# 0                         0.7258926         0.3534020
# 1                         0.2359394         0.5835702
# 2                         0.2512831         0.6596689
# 3                         0.4249015         0.3585251
# 4                         0.9830475         0.7999986
#
#    dimethylarginine (SDMA + ADMA)  dimethylglycine  diphenhydramine  \
# 0                       0.7260784        0.0822282        0.0000001
# 1                       0.3445059        0.2134995        0.0000001
# 2                       0.2712442        0.1505750        0.0000001
# 3                       0.5863317        0.0931315        0.0000001
# 4                       0.7973201        0.2985457        0.0000001
#
#    docosadienoate (22:2n6)  docosahexaenoate (DHA; 22:6n3)  \
# 0                0.9890088                       0.3614783
# 1                0.3063759                       0.3036839
# 2                0.7700289                       0.4273318
# 3                0.1428842                       0.4165954
# 4                0.9539193                       0.9425195
#
#    docosapentaenoate (n3 DPA; 22:5n3)  docosapentaenoate (n6 DPA; 22:5n6)  \
# 0                           0.5508019                           0.7589197
# 1                           0.1562558                           0.7451643
# 2                           0.2908641                           0.4520173
# 3                           0.4411924                           0.0000001
# 4                           0.9614721                           0.0000001
#
#    docosatrienoate (22:3n3)  dodecanedioate (C12-DC)  \
# 0                 0.9015724                0.8003105
# 1                 0.3915507                0.5668935
# 2                 0.3947544                0.3752652
# 3                 0.3560116                0.7010641
# 4                 0.0000001                0.4435047
#
#    Fibrinopeptide A, des-ala(1)*  eicosapentaenoate (EPA; 20:5n3)  \
# 0                      0.7177177                        0.2602746
# 1                      0.0000001                        0.2104776
# 2                      0.9911501                        0.3453325
# 3                      0.0000001                        0.2991553
# 4                      0.8380094                        0.9972140
#
#    eicosenoate (20:1)  epiandrosterone sulfate  ergothioneine  \
# 0           0.9751516                0.5453565      0.6110967
# 1           0.3151315                0.7257744      0.4847414
# 2           0.6141136                0.2852317      0.8987789
# 3           0.2470126                0.2658323      0.8137819
# 4           0.9097845                0.1381381      0.3947367
#
#    erucate (22:1n9)  erythritol  erythronate*  estrone 3-sulfate  \
# 0         0.9859892   0.1343939     0.1260909          0.8901813
# 1         0.2109230   0.1452408     0.1915148          0.8027923
# 2         0.9424505   0.0686031     0.1422160          0.0000001
# 3         0.1018805   0.4273997     0.1561589          0.7067617
# 4         0.5591718   0.5889813     0.8387480          0.0000001
#
#    ethanolamine  etiocholanolone glucuronide  ferulic acid 4-sulfate  \
# 0     0.1289653                    0.5563272               0.0000001
# 1     0.1506072                    0.4822334               0.7722897
# 2     0.1151089                    0.2961211               0.4712941
# 3     0.1041048                    0.2579202               0.8380426
# ...
# 2                           0.8575873               0.8027941
# 3                           0.0000001               0.7505390
# 4                           0.0000001               0.8218363
#
#    1-carboxyethylisoleucine  2'-O-methyluridine  androsterone glucuronide  \
# 0                 0.1505839           0.3451343                 0.5511876
# 1                 0.3888726           0.4304035                 0.5997613
# 2                 0.1314421           0.6709246                 0.1451541
# 3                 0.3367852           0.6110416                 0.2133775
# 4                 0.9694609           0.9756963                 0.0580047
#
#    glucuronide of C10H18O2 (8)*  3-methyladipoylcarnitine  12-HETE  \
# 0                     0.0000001                 0.3041583      nan
# 1                     0.0000001                 0.8027605      nan
# 2                     0.0000001                 0.5615700      nan
# 3                     0.0000001                 0.5011714      nan
# 4                     0.9999999                 0.8220147      nan
#
#    13-methylmyristate (i15:0)  1-methyl-4-imidazoleacetate  \
# 0                         nan                          nan
# 1                         nan                          nan
# 2                         nan                          nan
# 3                         nan                          nan
# 4                         nan                          nan
#
#    1-palmitoleoyl-GPE (16:1)*  2'-deoxyinosine  \
# 0                         nan              nan
# 1                         nan              nan
# 2                         nan              nan
# 3                         nan              nan
# 4                         nan              nan
#
#    2-eicosapentaenoyl-GPE (20:5)*  2-hydroxyibuprofen  \
# 0                             nan                 nan
# 1                             nan                 nan
# 2                             nan                 nan
# 3                             nan                 nan
# 4                             nan                 nan
#
#    2-methoxyacetaminophen glucuronide*  2-methoxyacetaminophen sulfate*  \
# 0                                  nan                              nan
# 1                                  nan                              nan
# 2                                  nan                              nan
# 3                                  nan                              nan
# 4                                  nan                              nan
#
#    2-stearoyl-GPC (18:0)*  5-acetylamino-6-formylamino-3-methyluracil  \
# 0                     nan                                         nan
# 1                     nan                                         nan
# 2                     nan                                         nan
# 3                     nan                                         nan
# 4                     nan                                         nan
#
#    5alpha-androstan-3alpha,17beta-diol monosulfate (1)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    5alpha-androstan-3beta,17beta-diol monosulfate (2)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#
#    furaneol sulfate  2-furoylcarnitine  N-acetylhistamine  \
# 0               nan                nan                nan
# 1               nan                nan                nan
# 2               nan                nan                nan
# 3               nan                nan                nan
# 4               nan                nan                nan
#
#    3-hydroxybutyroylglycine**  pyroglutamyllysine*  leucylglutamine*  \
# 0                         nan                  nan               nan
# 1                         nan                  nan               nan
# 2                         nan                  nan               nan
# 3                         nan                  nan               nan
# 4                         nan                  nan               nan
#
#    Fibrinopeptide A (7-16)*  2-methoxyresorcinol sulfate  \
# 0                       nan                          nan
# 1                       nan                          nan
# 2                       nan                          nan
# 3                       nan                          nan
# 4                       nan                          nan
#
#    phenylacetylhistidine  glutamine conjugate of C8H12O2 (2)*  \
# 0                    nan                                  nan
# 1                    nan                                  nan
# 2                    nan                                  nan
# 3                    nan                                  nan
# 4                    nan                                  nan
#
#    glyco-alpha-muricholate**  1-palmitoyl-GPA (16:0)  2-isopropylmalate  \
# 0                        nan                     nan                nan
# 1                        nan                     nan                nan
# 2                        nan                     nan                nan
# 3                        nan                     nan                nan
# 4                        nan                     nan                nan
#
#    5alpha-androstan-3alpha,17beta-diol 17-glucuronide  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    5alpha-androstan-3alpha,17alpha-diol monosulfate  azelate (C9-DC)  biotin  \
# 0                                               nan              nan     nan
# 1                                               nan              nan     nan
# 2                                               nan              nan     nan
# 3                                               nan              nan     nan
# 4                                               nan              nan     nan
#
#    bradykinin, hydroxy-pro(3)  chenodeoxycholate  cysteine sulfinic acid  \
# 0                         nan                nan                     nan
# 1                         nan                nan                     nan
# 2                         nan                nan                     nan
# 3                         nan                nan                     nan
# 4                         nan                nan                     nan
#
#    deoxycholate  folate  guanine  mead acid (20:3n9)  \
# 0           nan     nan      nan                 nan
# 1           nan     nan      nan                 nan
# 2           nan     nan      nan                 nan
# 3           nan     nan      nan                 nan
# 4           nan     nan      nan                 nan
#
#    N-acetylmethionine sulfoxide  N-palmitoyltaurine  p-aminobenzoate (PABA)  \
# 0                           nan                 nan                     nan
# 1                           nan                 nan                     nan
# 2                           nan                 nan                     nan
# 3                           nan                 nan                     nan
# 4                           nan                 nan                     nan
#
#    pyridoxine (Vitamin B6)  quinine  streptomycin  sucrose  \
# 0                      nan      nan           nan      nan
# 1                      nan      nan           nan      nan
# 2                      nan      nan           nan      nan
# 3                      nan      nan           nan      nan
# 4                      nan      nan           nan      nan
#
#    thiamin (Vitamin B1)  alpha-ketoglutaramate**  \
# 0                   nan                      nan
# 1                   nan                      nan
# 2                   nan                      nan
# 3                   nan                      nan
# 4                   nan                      nan
#
#    3-hydroxyindolin-2-one sulfate  methylnaphthyl sulfate (1)*  \
# 0                             nan                          nan
# 1                             nan                          nan
# 2                             nan                          nan
# 3                             nan                          nan
# 4                             nan                          nan
#
#          donor_id case_group case_control  age sex timepoint  time_to_tb  \
# 0  AHRI_06_donor4    AHRI_06         case   21   F        BL  14.0000000
# 1  AHRI_06_donor4    AHRI_06         case   21   F       M06   8.0000000
# 2  AHRI_06_donor1    AHRI_06      control   19   F        BL  14.0000000
# 3  AHRI_06_donor1    AHRI_06      control   19   F       M06   8.0000000
# 4  AHRI_06_donor3    AHRI_06      control   22   F        BL  14.0000000
#
#    site sample_type mpiib_group   set   revtp    group       site.gr smoke  \
# 0  AHRI      plasma    training  SET3  minus1     case     AHRI.case   NaN
# 1  AHRI      plasma    training  SET3    last     case     AHRI.case   NaN
# 2  AHRI      plasma    training  SET3  minus1  control  AHRI.control   NaN
# 3  AHRI      plasma    training  SET3    last  control  AHRI.control   NaN
# 4  AHRI      plasma    training  SET3  minus1  control  AHRI.control   NaN
#
#   fsmoke smokeyrs  tst
# 0    NaN      NaN    0
# 1    NaN      NaN  -99
# 2    NaN      NaN    0
# 3    NaN      NaN  -99
# 4    NaN      NaN    5

# %%
## HOW WELL DO SAMPLE PREPS CORRELATE?
#Extract donors for which there are multiple sample types at a given timepoint
dup_df = full_df[full_df.groupby(['donor_id', 'timepoint'])['sample_type'].transform('nunique') > 1] #ends up being only paired
#For each donor at each timepoint, calculate a correlation coefficient
dup_groups = dup_df.groupby(['donor_id', 'timepoint'])

corr = []
sig = []
donors = []
times = []
sample_types = []
for (donor, time), group in dup_groups:
    sample_types.append(group['sample_type'].values)
    donors.append(donor)
    times.append(time)
    
    shared_features = group[features[1:]].dropna(axis=1).T #drop columns that are not shared
    corr_temp, sig_temp = sp.stats.pearsonr(shared_features.values[:, 0], shared_features.values[:, 1])
    corr.append(corr_temp)
    sig.append(sig_temp)

corr_df = pd.DataFrame({'donor' : donors, 'timepoint' : times, 'sample_types' : sample_types, 
                        'Pearson correlation' : corr, 'p value' : sig, 'q value' : multi.multipletests(sig, method='fdr_bh')[1]})
display(corr_df)
#Result: all sample preps correlate significantly
# Out:
#             donor timepoint          sample_types  Pearson correlation  \
# 0   MAK_03_donor1        BL  [serum, plasma.RPMI]            0.6945510
# 1   MAK_03_donor2        BL  [serum, plasma.RPMI]            0.4701041
# 2   MAK_03_donor3        BL  [serum, plasma.RPMI]            0.6569617
# 3   MAK_03_donor4        BL  [serum, plasma.RPMI]            0.5876830
# 4   MAK_03_donor5        BL  [serum, plasma.RPMI]            0.5419694
# 5   MAK_04_donor3        BL  [serum, plasma.RPMI]            0.5275843
# 6   MAK_04_donor4        BL  [serum, plasma.RPMI]            0.4055235
# 7   MAK_04_donor5        BL  [serum, plasma.RPMI]            0.1103396
# 8   MAK_05_donor1        BL  [serum, plasma.RPMI]            0.4894127
# 9   MAK_05_donor2        BL  [serum, plasma.RPMI]            0.4938411
# 10  MAK_05_donor3        BL  [serum, plasma.RPMI]            0.5485980
# 11  MAK_05_donor4        BL  [serum, plasma.RPMI]            0.5077984
# 12  MAK_05_donor5        BL  [serum, plasma.RPMI]            0.4812739
# 13  MAK_08_donor1        BL  [serum, plasma.RPMI]            0.4723199
# 14  MAK_08_donor2        BL  [serum, plasma.RPMI]            0.4131710
# 15  MAK_08_donor4        BL  [serum, plasma.RPMI]            0.5659747
# 16  MAK_08_donor5        BL  [serum, plasma.RPMI]            0.6063559
# 17  MAK_09_donor1        BL  [serum, plasma.RPMI]            0.7000948
# 18  MAK_09_donor2        BL  [serum, plasma.RPMI]            0.5491344
# 19  MAK_09_donor3        BL  [serum, plasma.RPMI]            0.4668837
# 20  MAK_09_donor4        BL  [serum, plasma.RPMI]            0.5154958
# 21  MAK_09_donor5        BL  [serum, plasma.RPMI]            0.5866985
# 22  SUN_06_donor1        BL       [plasma, serum]            0.6334141
# 23  SUN_06_donor2        BL       [plasma, serum]            0.7351174
# 24  SUN_06_donor3        BL       [plasma, serum]            0.4983535
# 25  SUN_06_donor5        BL       [plasma, serum]            0.3502878
# 26  SUN_07_donor1        BL       [plasma, serum]            0.6487025
# 27  SUN_07_donor2        BL       [plasma, serum]            0.5998998
# 28  SUN_07_donor3        BL       [plasma, serum]            0.6682860
# 29  SUN_08_donor4        BL       [plasma, serum]            0.6143767
# 30  SUN_08_donor5        BL       [plasma, serum]            0.5785995
# 31  SUN_09_donor2        BL       [plasma, serum]            0.4861972
# 32  SUN_10_donor1        BL       [plasma, serum]            0.6362344
# 33  SUN_10_donor2        BL       [plasma, serum]            0.5733337
# 34  SUN_10_donor3        BL       [plasma, serum]            0.5846309
# 35  SUN_10_donor6        BL       [plasma, serum]            0.7121110
# 36  SUN_18_donor1        BL       [plasma, serum]            0.6563817
# 37  SUN_18_donor2        BL       [plasma, serum]            0.7493196
# 38  SUN_18_donor3        BL       [plasma, serum]            0.5806481
# 39  SUN_18_donor4        BL       [plasma, serum]            0.6488139
# 40  SUN_21_donor1        BL       [plasma, serum]            0.5536605
# 41  SUN_21_donor2        BL       [plasma, serum]            0.7239237
# 42  SUN_21_donor3        BL       [plasma, serum]            0.6214964
# 43  SUN_21_donor4        BL       [plasma, serum]            0.6262688
# 44  SUN_21_donor5        BL       [plasma, serum]            0.5793589
# 45  SUN_29_donor1        BL       [plasma, serum]            0.5913325
# 46  SUN_29_donor2        BL       [plasma, serum]            0.5025147
# 47  SUN_29_donor3        BL       [plasma, serum]            0.6175716
# 48  SUN_29_donor4        BL       [plasma, serum]            0.4840489
# 49  SUN_29_donor5        BL       [plasma, serum]            0.5439220
# 50  SUN_34_donor1        BL       [plasma, serum]            0.5084399
# 51  SUN_34_donor3        BL       [plasma, serum]            0.5664550
# 52  SUN_35_donor1        BL       [plasma, serum]            0.5926220
# 53  SUN_35_donor2        BL       [plasma, serum]            0.4836731
# 54  SUN_35_donor3        BL       [plasma, serum]            0.4004404
# 55  SUN_35_donor5        BL       [plasma, serum]            0.4979900
# 56  SUN_38_donor1        BL       [plasma, serum]            0.5353968
# 57  SUN_38_donor4        BL       [plasma, serum]            0.5684307
#
#      p value   q value
# 0  0.0000000 0.0000000
# 1  0.0000000 0.0000000
# 2  0.0000000 0.0000000
# 3  0.0000000 0.0000000
# 4  0.0000000 0.0000000
# 5  0.0000000 0.0000000
# 6  0.0000000 0.0000000
# 7  0.0111758 0.0111758
# 8  0.0000000 0.0000000
# 9  0.0000000 0.0000000
# 10 0.0000000 0.0000000
# 11 0.0000000 0.0000000
# 12 0.0000000 0.0000000
# 13 0.0000000 0.0000000
# 14 0.0000000 0.0000000
# 15 0.0000000 0.0000000
# 16 0.0000000 0.0000000
# 17 0.0000000 0.0000000
# 18 0.0000000 0.0000000
# 19 0.0000000 0.0000000
# 20 0.0000000 0.0000000
# 21 0.0000000 0.0000000
# 22 0.0000000 0.0000000
# 23 0.0000000 0.0000000
# 24 0.0000000 0.0000000
# 25 0.0000000 0.0000000
# 26 0.0000000 0.0000000
# 27 0.0000000 0.0000000
# 28 0.0000000 0.0000000
# 29 0.0000000 0.0000000
# 30 0.0000000 0.0000000
# 31 0.0000000 0.0000000
# 32 0.0000000 0.0000000
# 33 0.0000000 0.0000000
# 34 0.0000000 0.0000000
# 35 0.0000000 0.0000000
# 36 0.0000000 0.0000000
# 37 0.0000000 0.0000000
# 38 0.0000000 0.0000000
# 39 0.0000000 0.0000000
# 40 0.0000000 0.0000000
# 41 0.0000000 0.0000000
# 42 0.0000000 0.0000000
# 43 0.0000000 0.0000000
# 44 0.0000000 0.0000000
# 45 0.0000000 0.0000000
# 46 0.0000000 0.0000000
# 47 0.0000000 0.0000000
# 48 0.0000000 0.0000000
# 49 0.0000000 0.0000000
# 50 0.0000000 0.0000000
# 51 0.0000000 0.0000000
# 52 0.0000000 0.0000000
# 53 0.0000000 0.0000000
# 54 0.0000000 0.0000000
# 55 0.0000000 0.0000000
# 56 0.0000000 0.0000000
# 57 0.0000000 0.0000000

# %%
#WHAT METABOLITES DIFFER SIGNIFICANTLY?

#Bin by time, to show when we can start detecting changes in the bulk population
full_df['time_bin'] = np.floor(np.abs(full_df['time_to_tb'] / 6)) #6 month increments
met_tp = []
for (timepoint), group in full_df.groupby(['time_bin']):
    #group = group
    ctrl = group[group['group'].str.contains('control')][features[1:]].dropna(axis=1)
    case = group[group['group'].str.contains('case')][features[1:]].dropna(axis=1)
    
    all_metabs = significantMetabolites(ctrl, case, list(ctrl), labels)
    sig_metabs = all_metabs[all_metabs['q'] <= 0.05]
    #print('Timepoint : ' + str(timepoint))
    #display(sig_metabs)
    met_tp.append(all_metabs)
    
#Result: We only see a large number of significant metabolites <6 months to TB
sig_metab = met_tp[0][met_tp[0]['q'] <= 0.05]
display(sig_metab)

#Plot these for all individuals, color by site
# Out:
#                           metabolite      logFC  statistic   P.Value         q
# 157                          alanine -0.6015545  4.7984306 0.0000045 0.0014259
# 274                        histidine -0.5845999  4.7545860 0.0000061 0.0014259
# 457                        3-CMPFP** -0.5892701  4.6590098 0.0000083 0.0014259
# 191             C-glycosyltryptophan  0.4909619 -4.5034976 0.0000159 0.0016971
# 200                         cortisol  0.4359646 -4.3075366 0.0000165 0.0016971
# 513         androsterone glucuronide -0.5262275  3.9733464 0.0000709 0.0050393
# 469                 N1-methylinosine  0.2869066 -4.0678053 0.0000814 0.0050393
# 334                N-acetylcarnosine -0.5207245  4.0941218 0.0000823 0.0050393
# 248                        glutamine -0.5031270  4.0581694 0.0000882 0.0050393
# 110               3-ureidopropionate  0.4205190 -3.9608392 0.0001358 0.0069802
# 440                       tryptophan -0.4972497  3.8483498 0.0002083 0.0095662
# 509                       valine ion -0.4315735  3.6910435 0.0002233 0.0095662
# 512               2'-O-methyluridine  0.3873963 -3.7825593 0.0002502 0.0098912
# 360                        ornithine -0.4760020  3.6949878 0.0003436 0.0126139
# 70                2-hydroxydecanoate -0.4152937  3.5520907 0.0003822 0.0130961
# 379           phenylalanyltryptophan -0.4740411  3.5921622 0.0004965 0.0159486
# 342            N-acetylphenylalanine  0.3435299 -3.4236913 0.0006178 0.0186784
# 259          glycocholenate sulfate*  0.3881600 -3.3919097 0.0010031 0.0286443
# 508                6-bromotryptophan -0.4336890  3.3601685 0.0010734 0.0290384
# 237            gamma-glutamylalanine -0.4107916  3.2942097 0.0013364 0.0343444
# 143  5-methyluridine (ribothymidine) -0.3848189  3.2723373 0.0014035 0.0343518
# 480                      thioproline -0.3906724  3.1605726 0.0020408 0.0476811
# 312                       methionine -0.4061495  3.1401382 0.0021924 0.0489943

# %%
for i, df in enumerate(met_tp):
    sig = df[df['q'] <= 0.05]
    
    if len(sig) > 0:
        print('yes')
        with open('Diff_metab_table_'+str(i)+'.tex', 'w') as tf:
            tf.write(sig.to_latex())
     
print(len(met_tp[0]))
print(full_df['time_bin'].max())
# Out:
# yes
# yes
# 514
# 4.0

# %%
#Violin plot of selected metabolites
#CMPFP 
#cortisol
#glutamine
#lactate
metabs_to_plot = ['3-CMPFP**', 'cortisol', 'glutamine', 'lactate']
proximate = full_df[full_df['time_bin'] == 0]

fig, ax = plt.subplots(1, 4)
for i, ax in enumerate(ax):
    sns.violinplot(y=proximate[metabs_to_plot[i]], x=proximate['group'], ax=ax)

# %%
hmdb_ids = convertHMDB(sig_metab['metabolite'].values, chem_df)
sig_metab['hmdb'] = hmdb_ids
display(sig_metab)
# Out:
#                           metabolite      logFC  statistic   P.Value  \
# 157                          alanine -0.6015545  4.7984306 0.0000045
# 274                        histidine -0.5845999  4.7545860 0.0000061
# 457                        3-CMPFP** -0.5892701  4.6590098 0.0000083
# 191             C-glycosyltryptophan  0.4909619 -4.5034976 0.0000159
# 200                         cortisol  0.4359646 -4.3075366 0.0000165
# 513         androsterone glucuronide -0.5262275  3.9733464 0.0000709
# 469                 N1-methylinosine  0.2869066 -4.0678053 0.0000814
# 334                N-acetylcarnosine -0.5207245  4.0941218 0.0000823
# 248                        glutamine -0.5031270  4.0581694 0.0000882
# 110               3-ureidopropionate  0.4205190 -3.9608392 0.0001358
# 440                       tryptophan -0.4972497  3.8483498 0.0002083
# 509                       valine ion -0.4315735  3.6910435 0.0002233
# 512               2'-O-methyluridine  0.3873963 -3.7825593 0.0002502
# 360                        ornithine -0.4760020  3.6949878 0.0003436
# 70                2-hydroxydecanoate -0.4152937  3.5520907 0.0003822
# 379           phenylalanyltryptophan -0.4740411  3.5921622 0.0004965
# 342            N-acetylphenylalanine  0.3435299 -3.4236913 0.0006178
# 259          glycocholenate sulfate*  0.3881600 -3.3919097 0.0010031
# 508                6-bromotryptophan -0.4336890  3.3601685 0.0010734
# 237            gamma-glutamylalanine -0.4107916  3.2942097 0.0013364
# 143  5-methyluridine (ribothymidine) -0.3848189  3.2723373 0.0014035
# 480                      thioproline -0.3906724  3.1605726 0.0020408
# 312                       methionine -0.4061495  3.1401382 0.0021924
#
#             q       hmdb
# 157 0.0014259  HMDB00161
# 274 0.0014259  HMDB00177
# 457 0.0014259        NaN
# 191 0.0016971        NaN
# 200 0.0016971  HMDB00063
# 513 0.0050393  HMDB02829
# 469 0.0050393  HMDB02721
# 334 0.0050393  HMDB12881
# 248 0.0050393  HMDB00641
# 110 0.0069802  HMDB00026
# 440 0.0095662  HMDB00929
# 509 0.0095662        NaN
# 512 0.0098912        NaN
# 360 0.0126139  HMDB03374
# 70  0.0130961        NaN
# 379 0.0159486  HMDB29006
# 342 0.0186784  HMDB00512
# 259 0.0286443        NaN
# 508 0.0290384        NaN
# 237 0.0343444  HMDB29142
# 143 0.0343518  HMDB00884
# 480 0.0476811        NaN
# 312 0.0489943  HMDB00696

# %%
near_tb = met_tp[0]
log2fc = near_tb['logFC']
log10p = -np.log10(near_tb['P.Value'])
sig = near_tb['q'] <= 0.05
fig, ax = plt.subplots(1, 1)
sns.scatterplot(x=log2fc.values, y=log10p.values, hue=sig.values, ax=ax)
ax.get_legend().remove()
ax.set_xlabel('Log$_{2}$ fold change')
ax.set_ylabel('Log$_{10}$ p value')
fig.savefig('Diff_metab_volcano.pdf')

# %%
#Convert diff exp metabs to tmod format
hmdb_ids = convertHMDB(near_tb['metabolite'].values, chem_df)
near_tb['hmdb'] = hmdb_ids

metab_ids = [chem_df.loc[i, 'id'] if pd.isnull(id) else id for i, id in enumerate(hmdb_ids)]
near_tb['metab_ids'] = metab_ids

near_tb = near_tb.drop_duplicates(subset='hmdb')
near_tb = near_tb.sort_values(by='P.Value')
near_tb = near_tb.reset_index(drop=True)
near_tb.to_csv('./tmod_diff.txt', sep='\t')

msea_metabs = near_tb.dropna(axis=0)
msea_metabs = msea_metabs.set_index('hmdb')
msea_metabs = msea_metabs.drop(columns=['metabolite', 'q', 'metab_ids'])
msea_metabs = msea_metabs.reset_index(drop=False)
msea_metabs = msea_metabs.rename({'hmdb':'feature'}, axis='columns')


msea_metabs.to_csv('./stats_table.txt', sep='\t')

msea_metabs.head()
# Out:
#      feature      logFC  statistic   P.Value
# 0  HMDB00177 -0.8864468  4.5013579 0.0000068
# 1  HMDB00094 -0.8574287  3.9513166 0.0000777
# 2  HMDB00026  0.5264351 -3.6313947 0.0002819
# 3  HMDB00929 -0.7180533  3.6033314 0.0003142
# 4  HMDB00063  0.4993148 -3.5247541 0.0004239

# %%
met_tp_site = []
near_tb = full_df[full_df['time_bin'] == 0]
for (site), group in near_tb.groupby(['site']):
    ctrl = group[group['group'].str.contains('control')][features[1:]].dropna(axis=1)
    case = group[group['group'].str.contains('case')][features[1:]].dropna(axis=1)
    
    all_metabs = significantMetabolites(ctrl, case, list(ctrl), labels)
    sig_metabs = all_metabs[all_metabs['q'] <= 0.05]
    #print('Timepoint : ' + str(timepoint))
    display(sig_metabs)
    met_tp_site.append(all_metabs)
# Out:
# Empty DataFrame
# Columns: [metabolite, logFC, statistic, P.Value, q]
# Index: []
# Empty DataFrame
# Columns: [metabolite, logFC, statistic, P.Value, q]
# Index: []
#                                             metabolite      logFC  statistic  \
# 308                                             fucose -1.2249319  4.0285311
# 312                              gamma-glutamylalanine -0.9932775  3.6710835
# 522                             phenylalanyltryptophan -1.0568231  3.6517620
# 192                                        9,10-DiHOME -1.2169110  3.6421013
# 224                              asparaginylisoleucine  0.9176894 -4.0466808
# 88                                  2-hydroxydecanoate -1.0530323  3.5165116
# 654  glucuronide of piperine metabolite C17H21NO3 (4)* -0.7497348  3.4875293
# 676      sulfate of piperine metabolite C16H19NO3 (3)* -0.7733440  3.4778686
# 328                                          glutamine -0.9705304  3.4199041
# 661      sulfate of piperine metabolite C16H19NO3 (2)* -0.8067896  3.4005826
# 583                                            taurine  0.5396861 -3.4005826
# 462                                 N-acetylmethionine  0.6340339 -3.3812611
# 314                            gamma-glutamylglutamine -0.9443823  3.3619396
#
#       P.Value         q
# 308 0.0000561 0.0426561
# 312 0.0002415 0.0452475
# 522 0.0002604 0.0452475
# 192 0.0002704 0.0452475
# 224 0.0003394 0.0452475
# 88  0.0004373 0.0452475
# 654 0.0004875 0.0452475
# 676 0.0005054 0.0452475
# 328 0.0006264 0.0452475
# 661 0.0006724 0.0452475
# 583 0.0006724 0.0452475
# 462 0.0007215 0.0452475
# 314 0.0007740 0.0452475
# Empty DataFrame
# Columns: [metabolite, logFC, statistic, P.Value, q]
# Index: []

# %%
#WHAT METABOLITES CORRELATE WITH RISK? 
#analyzing separately by sample type (as broad as possible, color by location)
#spearman correlation with progressor status (y/n)
#pearson correlation with time to tb (metabolite-by-metabolite) 
#for a select few, show ones that go up, down, etc. relative to controls
all_case = full_df[full_df['group'].str.contains('case')].sort_values(by='case_group')
all_ctrl = full_df[full_df['group'].str.contains('control')].sort_values(by='case_group')


match_groups = np.unique([all_case['case_group'] + all_case['timepoint']]) #filter out 
all_groups = all_ctrl['case_group'] + all_ctrl['timepoint']
ctrl_keep = [(x in match_groups) for x in all_groups]

corr_bulk = []
sig_bulk = []
corr_matched = []
sig_matched = []
corr_biserial = []
sig_biserial = []
for metab in features[1:]:
    tb_time = all_case['time_to_tb']
    metab_values = all_case[metab] 
    
    metab_ratio = (all_case.groupby(['case_group', 'timepoint'])[metab].mean().values / 
                   all_ctrl[ctrl_keep].groupby(['case_group', 'timepoint'])[metab].mean().values)
    tb_time_matched = all_case.groupby(['case_group', 'timepoint'])['time_to_tb'].mean().values
    
    corr_bulk_temp, sig_bulk_temp = sp.stats.spearmanr(metab_values, tb_time, nan_policy='omit')
    corr_bulk.append(corr_bulk_temp)
    sig_bulk.append(sig_bulk_temp)
    
    corr_matched_temp, sig_matched_temp = sp.stats.spearmanr(metab_ratio, tb_time_matched, nan_policy='omit')
    corr_matched.append(corr_matched_temp)
    sig_matched.append(sig_matched_temp)
    
corr_df = pd.DataFrame({'metab' : features[1:], 
                        'Spearman_bulk' : corr_bulk, 'Spearman_matched' : corr_matched,
                        'p_bulk' : sig_bulk, 'p_matched' : sig_matched,
                        'q_bulk' : multi.multipletests(sig_bulk, method='fdr_bh')[1], 
                        'q_matched' : multi.multipletests(sig_matched, method='fdr_bh')[1]})
#display(corr_df_bulk.sort_values(by='q value'))

sig_corr_bulk = corr_df[corr_df['q_bulk'] <= 0.05]
sig_corr_matched = corr_df[corr_df['q_matched'] <= 0.05]
display(corr_df.sort_values(by='q_bulk'))

#In lumped analysis, there are some metabs that correlate with time to TB
#Venn diagram of significant metabolites that correlate with time to TB

#Progressor vs. control spearman R
# Out:
#                                                  metab  Spearman_bulk  \
# 835   5alpha-androstan-3alpha,17alpha-diol monosulfate            nan
# 810                                         omeprazole            nan
# 849                                            quinine            nan
# 845                       N-acetylmethionine sulfoxide            nan
# 392                                  isoleucyltyrosine            nan
# 398                                         kynurenine     -0.2940130
# 655                                          3-CMPFP**      0.2762573
# 286                     dimethylarginine (SDMA + ADMA)     -0.2610579
# 752                     glycine conjugate of C10H12O2*      0.2676411
# 146                                 3-ureidopropionate     -0.2590423
# 41                                  N-methylpipecolate     -0.2567290
# 241                                         biliverdin      0.2547611
# 163                                 4-imidazoleacetate     -0.2523695
# 446                      N6-carbamoylthreonyladenosine     -0.2483846
# 399                                            lactate     -0.2427376
# 128                                 3-hydroxydecanoate      0.2417024
# 714                        1-carboxyethylphenylalanine     -0.2392488
# 72                                     2-aminobutyrate      0.2379795
# 204                                          allantoin     -0.2327413
# 252                               C-glycosyltryptophan     -0.2343217
# 463                                N-acetylneuraminate     -0.2396336
# 74                                    2-aminooctanoate      0.2301271
# 238                                   bilirubin (E,E)*      0.2267787
# 369                                          HWESASXX*     -0.2259346
# 224                              asparaginylisoleucine     -0.3146364
# 753                 glycine conjugate of C10H14O2 (1)*      0.2310816
# 785                                  glutarate (C5-DC)      0.3350620
# 467                                  N-acetylthreonine     -0.2216777
# 445                                    N6-acetyllysine     -0.2190858
# 671                                   N1-methylinosine     -0.2195917
# 333                                           glycerol      0.2188992
# 336                     glycerophosphorylcholine (GPC)     -0.2151802
# 458                                    N-acetylglycine      0.2147803
# 131                                 3-hydroxyoctanoate      0.2146703
# 464                              N-acetylphenylalanine     -0.2162846
# 483                                 N-palmitoylglycine      0.2111068
# 124  3-carboxy-4-methyl-5-propyl-2-furanpropanoate ...      0.2092220
# 266                                           cortisol     -0.2057613
# 525                                phenyllactate (PLA)     -0.2053862
# 650                                        XHWESASXXR*     -0.2121465
# 427                                   margarate (17:0)      0.2028009
# 228                                    aspartylleucine     -0.2010815
# 348                                      glycylproline     -0.2057701
# 495                                   palmitate (16:0)      0.1994427
# 757                           androsterone glucuronide      0.1954591
# 681                          N-acetyl-2-aminooctanoate      0.1957878
# 651                                            xylitol     -0.1939224
# 10                                        12,13-DiHOME      0.1994952
# 462                                 N-acetylmethionine     -0.1913499
# 132                                3-hydroxypropanoate     -0.1873196
# 425                                           mannitol     -0.1860556
# 313                            gamma-glutamylglutamate     -0.2591663
# 279                                           cytidine     -0.1861894
# 413                                 linoleate (18:2n6)      0.1854074
# 563                                       serylproline     -0.2571684
# 239                            bilirubin (E,Z or Z,E)*      0.2549605
# 482                               nonadecanoate (19:0)      0.1822953
# 8                              10-undecenoate (11:1n1)      0.1828544
# 488                                    oleate (18:1n9)      0.1815516
# 296                    eicosapentaenoate (EPA; 20:5n3)      0.1809043
# 186     7-alpha-hydroxy-3-oxo-4-cholestenoate (7-Hoca)     -0.1787233
# 259                                   cinnamoylglycine      0.1772561
# 573                                    stearate (18:0)      0.1775643
# 358                             hexanoylcarnitine (C6)      0.1776064
# 415         linolenate [alpha or gamma; (18:3n3 or 6)]      0.1743387
# 301                                         erythritol     -0.1743186
# 167                                 5,6-dihydrothymine     -0.1760154
# 749                                  6-bromotryptophan      0.1736828
# 695                               1-carboxyethylvaline     -0.1733312
# 708                                 phenylalanyllysine     -0.2391054
# 709                                     cyclo(pro-val)      0.1697166
# 133                                  3-hydroxysebacate      0.1757445
# 7                            10-nonadecenoate (19:1n9)      0.1707910
# 722                                  pimeloylcarnitine      0.1755701
# 172      5alpha-androstan-3beta,17alpha-diol disulfate      0.1693020
# 89                                  2-hydroxyglutarate     -0.1739665
# 78                                     2'-deoxyuridine     -0.1759828
# 730                              umbelliferone sulfate      0.1747675
# 435                                   myristate (14:0)      0.1696128
# 214                               androsterone sulfate      0.1692595
# 283                          dihomo-linoleate (20:2n6)      0.1766354
# 291                 docosapentaenoate (n3 DPA; 22:5n3)      0.1690015
# 541                                      pseudouridine     -0.1709634
# 649                                       xanthurenate      0.1798402
# 597                                          threonine      0.1728817
# 442                            N2,N2-dimethylguanosine     -0.1753990
# 377                               imidazole propionate     -0.1732925
# 497                              palmitoleate (16:1n7)      0.1676204
# 368                                          HWESASLLR     -0.2226027
# 262                             cis-vaccenate (18:1n7)      0.1675826
# 613                                tryptophylglutamate     -0.1721625
# 436                              myristoleate (14:1n5)      0.1655270
# 583                                            taurine     -0.1632649
# 79                       2-docosahexaenoyl-GPC (22:6)*      0.1637366
# 168                                  5,6-dihydrouracil     -0.1634777
# 218                                  arachidate (20:0)      0.1621599
# 691                     glycochenodeoxycholate sulfate     -0.2155770
# 229                              aspartylphenylalanine     -0.1669966
# 328                                          glutamine      0.1618127
# 297                                 eicosenoate (20:1)      0.1601932
# 19                           1-arachidonoyl-GPA (20:4)      0.1604749
# 104                            2-oleoylglycerol (18:1)      0.2131895
# 49                             1-oleoylglycerol (18:1)      0.1601360
# 574                              stearidonate (18:4n3)      0.1604208
# 302                                       erythronate*     -0.1591371
# 540                                   propionylglycine      0.1621020
# 6                           10-heptadecenoate (17:1n7)      0.1569518
# 515                                phenylalanylglycine     -0.1613878
# 735                             1-carboxyethyltyrosine     -0.1602253
# 158                               4-ethylphenylsulfate      0.1552071
# 745  glucuronide of piperine metabolite C17H21NO3 (5)*      0.1590858
# 818                                     tigloylglycine      0.2333492
# 177                             5-dodecenoate (12:1n7)      0.1519191
# 567                                           sorbitol     -0.1532479
# 654  glucuronide of piperine metabolite C17H21NO3 (4)*      0.1571055
# 694                          glycodeoxycholate sulfate      0.1523339
# 517                                phenylalanylleucine     -0.1520335
# 799                                  isovalerylglycine      0.2306163
# 830                glutamine conjugate of C8H12O2 (2)*      0.2304850
# 290                     docosahexaenoate (DHA; 22:6n3)      0.1509834
# 529                                           piperine      0.1499281
# 684                            N-acetyl-isoputreanine*     -0.1500363
# 295                      Fibrinopeptide A, des-ala(1)*     -0.1498578
# 659                                 5,6-dihydrouridine     -0.1504431
# 741                                   3-hydroxylaurate      0.1535659
# 733                              1-carboxyethylleucine     -0.1490805
# 192                                        9,10-DiHOME      0.2094878
# 424                                        maltotriose     -0.2048735
# 543                                     pyroglutamine*     -0.1461610
# 352                                   guanidinoacetate      0.1467897
# 383                                            inosine     -0.1461286
# 710                              phenylalanylthreonine     -0.2065612
# 452                            N-acetylaspartate (NAA)      0.1459035
# 465                                 N-acetylputrescine     -0.1503586
# 780                                dihydroferulic acid      0.2115496
# 466                                     N-acetylserine     -0.1508173
# 303                                  estrone 3-sulfate      0.1459715
# 625                               tyrosylphenylalanine     -0.2050274
# 127                           3-hydroxybutyrate (BHBA)      0.1465476
# 477                              nicotinamide riboside     -0.2048905
# 547                                           pyruvate     -0.1454312
# 693                     3-hydroxyhexanoylcarnitine (1)      0.1492502
# 443                                 N2-methylguanosine     -0.1481356
# 715                                 tyramine O-sulfate     -0.1441804
# 165                           4-methylcatechol sulfate      0.1438860
# 346                                      glycylleucine     -0.1441910
# 298                            epiandrosterone sulfate      0.1415197
# 725                       glucuronide of C10H18O2 (7)*      0.1449357
# 514                              phenylalanylglutamate     -0.1447531
# 159                               4-guanidinobutanoate     -0.1402997
# 642                                        valylserine     -0.1965560
# 340                            glycocholenate sulfate*     -0.1396052
# 562                                  serylphenyalanine     -0.1947365
# 571                            sphingosine 1-phosphate     -0.1367794
# 662                  3,4-methylene heptanoyl carnitine      0.1368666
# 648                                         xanthosine     -0.1375940
# 250                                          carnitine      0.1370135
# 240                                    bilirubin (Z,Z)      0.1371757
# 702                             alpha-glutamylleucine*     -0.1919249
# 474                                 N-formylmethionine     -0.1358232
# 210                           alpha-hydroxyisovalerate     -0.1359467
# 656                                      hydroxy-CMPF*      0.1347287
# 268                                           cotinine      0.1349682
# 812                                prolylphenylalanine      0.2056423
# 363                                 histidyltryptophan     -0.1388049
# 510                                      phenylalanine     -0.1349691
# 666                               N6-succinyladenosine     -0.1341054
# 469                                   N-acetyltyrosine     -0.1335762
# 289                            docosadienoate (22:2n6)      0.1328457
# 634                              valerylcarnitine (C5)      0.1317634
# 94                                   2-hydroxystearate      0.1308721
# 696                               dopamine 3-O-sulfate     -0.1308514
# 147                               4-acetamidobutanoate     -0.1304669
# 698                                         acesulfame     -0.1350297
# 740                             dodecadienoate (12:2)*      0.1314205
# 277                     cysteine-glutathione disulfide     -0.1308914
# 720                           Fibrinopeptide A (5-16)*     -0.1357417
# 318                        gamma-glutamylphenylalanine     -0.1306549
# 270                                           creatine      0.1305228
# 196                                            adenine     -0.1333251
# 461                                    N-acetylleucine     -0.1294481
# 400                                        lathosterol      0.1323637
# 189                                    7-methylguanine     -0.1276184
# 185                      6-oxopiperidine-2-carboxylate     -0.1278111
# 50                                 1-oleoyl-GPA (18:1)      0.1794068
# 519                          phenylalanylphenylalanine     -0.1274064
# 88                                  2-hydroxydecanoate      0.1276469
# 275                                  cys-gly, oxidized     -0.1695842
# 626                                    tyrosyltyrosine     -0.1769241
# 492                                          ornithine      0.1257574
# 11                                    13-HODE + 9-HODE      0.1257628
# 765                     2-eicosapentaenoyl-GPE (20:5)*      0.1916860
# 839                                  chenodeoxycholate     -0.5600663
# 384                         inositol 1-phosphate (I1P)      0.1253239
# 610                                         tryptophan      0.1246413
# 449                                    N-acetylalanine     -0.1238510
# 448                           N6,N6,N6-trimethyllysine     -0.1239554
# 87                             2-hydroxybutyrate (AHB)      0.1223757
# 269                                   cotinine N-oxide      0.1257426
# 247                                     caprate (10:0)      0.1222020
# 487                             octanoylcarnitine (C8)      0.1224851
# 230                                     aspartylvaline     -0.1263827
# 217                                          arabonate      0.1214725
# 538                                      prolylglycine     -0.1249972
# 67                               1-stearoyl-GPI (18:0)     -0.1196581
# 581                                          tartarate      0.1197405
# 746  glucuronide of piperine metabolite C17H21NO3 (3)*      0.1233535
# 151                              4-allylphenol sulfate      0.1199047
# 28                      1-eicosapentaenoyl-GPC (20:5)*      0.1202610
# 588                                  taurodeoxycholate      0.1197729
# 360                                          histidine      0.1182271
# 429                                         methionine      0.1181860
# 364                                       homoarginine     -0.1218326
# 614                                  tryptophylglycine     -0.1213183
# 294                            dodecanedioate (C12-DC)      0.1169489
# 536                                            proline      0.1163771
# 15                           17-methylstearate (i19:0)      0.1165219
# 755                           1-carboxyethylisoleucine     -0.1160012
# 605                          tiglylcarnitine (C5:1-DC)      0.1157509
# 478                                 N-linoleoylglycine      0.1189380
# 718                                   sulfamethoxazole     -0.1152135
# 71                                      2-aminoadipate     -0.1148906
# 575                stearoyl sphingomyelin (d18:1/18:0)     -0.1143741
# 341                                  glycodeoxycholate      0.1132355
# 225                                 asparaginylleucine     -0.1591843
# 441                                 N1-methylguanosine     -0.1133047
# 726                                          pyrraline      0.1126751
# 697                           vanillic alcohol sulfate     -0.1160982
# 778                                            codeine     -0.1709720
# 264                                         citrulline      0.1125347
# 631                                               urea      0.1121956
# 207                               alpha-glutamylvaline     -0.1571216
# 260                    cis-4-decenoylcarnitine (C10:1)      0.1118125
# 553                       S-adenosylhomocysteine (SAH)     -0.1116801
# 107                               2'-O-methylguanosine      0.1142282
# 528                                         pipecolate     -0.1110279
# 13                          16a-hydroxy DHEA 3-sulfate     -0.1109896
# 116                         3-(4-hydroxyphenyl)lactate     -0.1106837
# 322                                   gamma-tocopherol     -0.1137876
# 533               pregnenediol disulfate (C21H34O8S2)*     -0.1097144
# 779                                cyclo(L-phe-D-pro)*      0.1669758
# 687                                        thioproline      0.1097335
# 661      sulfate of piperine metabolite C16H19NO3 (2)*      0.1133592
# 579                          succinylcarnitine (C4-DC)     -0.1090219
# 645                                        valylvaline     -0.1533357
# 164                           4-methyl-2-oxopentanoate      0.1092008
# 171  5alpha-androstan-3alpha,17beta-diol monosulfat...      0.1092077
# 73                                   2-aminoheptanoate      0.1094472
# 689                                  hexanoylglutamine      0.1078374
# 665                              5-dodecenoylcarnitine      0.1074394
# 459                                  N-acetylhistidine      0.1075603
# 522                             phenylalanyltryptophan      0.1066170
# 854                     3-hydroxyindolin-2-one sulfate     -0.4862114
# 194                               acetylcarnitine (C2)      0.1061150
# 680                          hexadecadienoate (16:2n6)      0.1054283
# 353                                          guanosine     -0.1052694
# 723                            4-hydroxychlorothalonil     -0.1087582
# 658                        1-ribosyl-imidazoleacetate*     -0.1053845
# 758                       glucuronide of C10H18O2 (8)*      0.1079728
# 200                                  adrenate (22:4n6)      0.1040095
# 24                       1-docosahexaenoyl-GPC (22:6)*      0.1040055
# 365                                     homocitrulline     -0.1041982
# 828                        2-methoxyresorcinol sulfate      0.1573216
# 707                               pyroglutamylleucine*     -0.1036247
# 361                                    histidylalanine     -0.1067072
# 372                                    hydroxycotinine      0.1034613
# 838                         bradykinin, hydroxy-pro(3)      0.4714952
# 96                          2-linoleoylglycerol (18:2)      0.1441036
# 580                                           sulfate*      0.1019808
# 591                         tetradecanedioate (C14-DC)      0.1019833
# 367                                   homostachydrine*      0.1014860
# 91                                2-hydroxyisobutyrate      0.0996302
# 60                             1-palmitoyl-GPG (16:0)*     -0.1002077
# 190                                      7-methylurate      0.1343365
# 819                                epsilon-caprolactam      0.1435834
# 280                            decanoylcarnitine (C10)      0.0997554
# 288                                    diphenhydramine      0.1403318
# 831                          glyco-alpha-muricholate**      0.1522221
# 476           nicotinamide adenine dinucleotide (NAD+)     -0.1400532
# 145                3-phenylpropionate (hydrocinnamate)      0.0987239
# 347                                glycylphenylalanine     -0.0987094
# 5                                    1,7-dimethylurate      0.0986907
# 711                             pyroglutamylisoleucine      0.1009450
# 410                                     leukotriene B5     -0.1378107
# 481                                    N-oleoyltaurine      0.0965285
# 837                                             biotin      0.4444783
# 57                          1-palmitoylglycerol (16:0)      0.0956286
# 179                                 5-hydroxyhexanoate     -0.1280212
# 612                               tryptophylasparagine     -0.0983523
# 337                                            glycine      0.0933696
# 2                                    1,3-dimethylurate      0.0938852
# 850                                       streptomycin      0.4259584
# 523                                 phenylalanylvaline     -0.0953060
# 355                                              HEPES     -0.1227068
# 411                         levulinate (4-oxovalerate)     -0.0952286
# 509                                phenylacetylglycine     -0.1238237
# 401                                     laurate (12:0)      0.0946935
# 493                                 O-sulfo-L-tyrosine     -0.0941117
# 391                                 isoleucylthreonine     -0.0956312
# 349                                   glycyltryptophan     -0.0959464
# 630                                              urate     -0.0917185
# 161                             4-hydroxyphenylacetate     -0.0937681
# 734                          2-hydroxyfluorene sulfate      0.1218152
# 253                                     chiro-inositol      0.0937437
# 261                                     cyclo(ala-pro)      0.0950520
# 103                            2-myristoyl-GPC (14:0)*     -0.0950056
# 102                         2-myristoylglycerol (14:0)     -0.1336785
# 166                              4-vinylphenol sulfate      0.0927601
# 602                                    threonylproline     -0.1307189
# 242                                         bradykinin     -0.0947299
# 748                           glyco-beta-muricholate**      0.0944758
# 678                                     2-oxoarginine*     -0.0916145
# 201                                  Fibrinopeptide A*     -0.0932364
# 285                                   dimethyl sulfone      0.0932274
# 807                                    methylphosphate     -0.1441470
# 660                   methyl-4-hydroxybenzoate sulfate      0.0911157
# 808                                    N2-acetyllysine     -0.1390906
# 176  5alpha-pregnan-3beta,20alpha-diol monosulfate (2)      0.0937166
# 123                        3b-hydroxy-5-cholenoic acid      0.1300269
# 149                            4-acetaminophen sulfate      0.0896791
# 677                                 phenol glucuronide     -0.1256802
# 682                                         argininate     -0.0888853
# 374                                       hypoxanthine     -0.0889953
# 206                           alpha-glutamyltryptophan     -0.1254054
# 130                               3-hydroxyisobutyrate      0.0893903
# 211                                alpha-ketoglutarate     -0.0890111
# 728                       lithocholic acid sulfate (1)     -0.0903661
# 621                                   tyrosylhistidine     -0.1271156
# 267                                          cortisone     -0.0895004
# 447                                 N6-methyladenosine     -0.1260006
# 609                             trimethylamine N-oxide     -0.0917376
# 431                                    methionylvaline     -0.1245198
# 781                                            ectoine      0.1344453
# 22                      1-dihomo-linoleoyl-GPC (20:2)*     -0.0880661
# 841                                       deoxycholate     -0.4062019
# 674                  3-S-cysteinyl-2-methylpropanoate*     -0.0870039
# 27                    1-docosapentaenoyl-GPC (22:5n6)*     -0.0871914
# 170      5alpha-androstan-3alpha,17beta-diol disulfate      0.0872808
# 657                   propyl 4-hydroxybenzoate sulfate      0.0874872
# 414                            linoleate, methyl ester      0.0863330
# 744                                      p-toluic acid      0.1218279
# 598                                  threonylglutamate     -0.1211422
# 180                             5-hydroxyindoleacetate     -0.0860089
# 844                                 mead acid (20:3n9)      0.4000473
# 154        androstenediol (3beta,17beta) disulfate (1)     -0.0856394
# 751                            6-hydroxyindole sulfate     -0.0841067
# 683                               5-methylthioribose**     -0.0849992
# 453                 N-acetyl-aspartyl-glutamate (NAAG)      0.0845807
# 202                                            alanine      0.0839804
# 222                              ascorbate (Vitamin C)      0.0866196
# 12                          15-methylpalmitate (i17:0)      0.0839962
# 600                                    threonylleucine     -0.0865907
# 622                                  tyrosylisoleucine     -0.1189329
# 263                                            citrate      0.0838675
# 244                              butyrylcarnitine (C4)      0.0841350
# 14                                 16-hydroxypalmitate      0.0836790
# 35                          1-linoleoylglycerol (18:2)      0.0834239
# 84                                2-ethylphenylsulfate     -0.0831768
# 587                             taurocholenate sulfate     -0.0830565
# 599                                 threonylisoleucine     -0.1160107
# 712                                 dopamine 4-sulfate     -0.0821222
# 627                                      tyrosylvaline     -0.1154157
# 29                      1-eicosapentaenoyl-GPE (20:5)*      0.1095188
# 475                                       nicotinamide     -0.0814457
# 732                             myristoleoylcarnitine*      0.0814346
# 460                                 N-acetylisoleucine     -0.0812207
# 783                              gamma-glutamylglycine     -0.1240963
# 30              1-dihomo-linolenoyl-GPC (20:3n3 or 6)*     -0.0812783
# 790                                hydrochlorothiazide      0.1232004
# 232                                       beta-alanine     -0.0803027
# 321                               gamma-glutamylvaline     -0.0796370
# 592                                           theanine      0.0793491
# 456                                  N-acetylglutamate      0.0789174
# 199                   adenosine 5'-monophosphate (AMP)     -0.0785753
# 789                         hydantoin-5-propionic acid     -0.1123705
# 775                                           atenolol      0.1192972
# 1                                 1,3,7-trimethylurate      0.0781346
# 281            dehydroisoandrosterone sulfate (DHEA-S)      0.0776163
# 690                            4-vinylguaiacol sulfate      0.0772184
# 794                                 isoleucylglutamate     -0.1176853
# 508                              phenylacetylglutamine     -0.0775711
# 93                                  2-hydroxypalmitate      0.0773534
# 82              2-dihomo-linolenoyl-GPC (20:3n3 or 6)*     -0.0771983
# 676      sulfate of piperine metabolite C16H19NO3 (3)*      0.0793044
# 378                           indole-3-carboxylic acid      0.0765968
# 652                                           xylonate     -0.0764606
# 359                                          hippurate     -0.0763354
# 254                                            cholate     -0.0758405
# 774                             alpha-glutamyltyrosine      0.1143574
# 402                              laurylcarnitine (C12)      0.0753272
# 68                              1-stearoyl-GPS (18:0)*     -0.1056128
# 197                                          adenosine     -0.0751633
# 422                                             malate     -0.0748894
# 454                              N-acetyl-beta-alanine     -0.0752114
# 61                              1-palmitoyl-GPI (16:0)     -0.0740857
# 739                        methylnaphthyl sulfate (2)*      0.0739401
# 404                                      leucylalanine     -0.0760115
# 256                                            choline      0.0728777
# 565                                        serylvaline     -0.1029440
# 31              1-dihomo-linolenoyl-GPE (20:3n3 or 6)*     -0.0731528
# 624                                      tyrosyllysine     -0.1032157
# 9                             11-dehydrocorticosterone     -0.1035450
# 18                          1-arachidonoyl-GPI (20:4)*     -0.0730329
# 717                                gamma-CEHC sulfate*     -0.1024451
# 85                          2-hydroxy-3-methylvalerate     -0.0718941
# 847                             p-aminobenzoate (PABA)      0.3395320
# 315                          gamma-glutamylisoleucine*     -0.0709827
# 701                              pyroglutamylarginine*     -0.0999903
# 380                              indoleacetylglutamine      0.0712549
# 628                            undecanedioate (C11-DC)     -0.0949354
# 293                           docosatrienoate (22:3n3)      0.0706508
# 836                                    azelate (C9-DC)      0.3323470
# 485                                   o-cresol sulfate     -0.0696014
# 26                    1-docosapentaenoyl-GPC (22:5n3)*      0.0698660
# 440                                 N1-methyladenosine     -0.0696679
# 310                                         gamma-CEHC      0.0695231
# 736                                      tyrosylserine     -0.0978518
# 764                                    2'-deoxyinosine      0.1050525
# 595                                           threitol     -0.0685159
# 183                    5-methyluridine (ribothymidine)      0.0685357
# 406                                leucylphenylalanine     -0.0705506
# 114                             2-stearoyl-GPI (18:0)*     -0.0969199
# 316                              gamma-glutamylleucine     -0.0683373
# 58                              1-palmitoyl-GPC (16:0)     -0.0680670
# 20                        1-arachidonylglycerol (20:4)      0.0961030
# 134                                  3-indoxyl sulfate     -0.0674954
# 305                        etiocholanolone glucuronide      0.0667267
# 738                              phenylacetylglutamate     -0.0688305
# 653                                             xylose     -0.0666784
# 307                                           fructose      0.0667103
# 539                            propionylcarnitine (C3)      0.0661499
# 526                                     phenylpyruvate     -0.0880752
# 356                                   heptanoate (7:0)      0.0651607
# 407                                    leucylthreonine     -0.0922917
# 90                   2-hydroxyhippurate (salicylurate)     -0.0651316
# 520                                phenylalanylproline      0.0922821
# 824                         3-hydroxybutyroylglycine**      0.0934054
# 503                                   p-cresol sulfate      0.0648117
# 198        adenosine 3',5'-cyclic monophosphate (cAMP)      0.0644758
# 800                                   leucylasparagine      0.0974729
# 233                            beta-hydroxyisovalerate     -0.0639149
# 760                                            12-HETE     -0.0972370
# 527                                          phosphate      0.0637225
# 257                                  choline phosphate     -0.0896792
# 673                 N1-methyl-4-pyridone-3-carboxamide     -0.0632114
# 759                           3-methyladipoylcarnitine      0.0650264
# 0                                      1,2-propanediol     -0.0631812
# 4                                   1,6-anhydroglucose      0.0647372
# 578                                          succinate      0.0628224
# 396                                     I-urobilinogen     -0.0640074
# 317                           gamma-glutamylmethionine      0.0623816
# 312                              gamma-glutamylalanine     -0.0622131
# 585                             taurochenodeoxycholate     -0.0614421
# 63                         1-pentadecanoyl-GPC (15:0)*     -0.0616490
# 833                                  2-isopropylmalate     -0.2928363
# 457                                  N-acetylglutamine      0.0618596
# 47                              1-myristoyl-GPC (14:0)     -0.0612868
# 373                                         hyocholate     -0.0865802
# 549                            riboflavin (Vitamin B2)      0.0616077
# 338                             glycochenodeoxycholate     -0.0609432
# 148                                  4-acetamidophenol      0.0607019
# 546                                 pyroglutamylvaline     -0.0625697
# 284                   dihomo-linolenate (20:3n3 or n6)      0.0603088
# 506                                         phenol red     -0.0798726
# 287                                    dimethylglycine     -0.0611594
# 405                                      leucylglycine     -0.0615213
# 174                      5alpha-pregnan-diol disulfate     -0.0601244
# 419                                    lysylisoleucine     -0.0840033
# 848                            pyridoxine (Vitamin B6)      0.2839723
# 545                                pyroglutamylglycine     -0.0617343
# 265                                     corticosterone     -0.0788991
# 633                                   ursodeoxycholate      0.0580143
# 136                                  3-methoxytyrosine     -0.0584219
# 699                                 ferulylglycine (1)     -0.0817962
# 468                                 N-acetyltryptophan     -0.0586288
# 3                         1,5-anhydroglucitol (1,5-AG)     -0.0580042
# 840                             cysteine sulfinic acid      0.2777989
# 40                             1-margaroyl-GPE (17:0)*      0.0813977
# 43                                1-methylnicotinamide      0.0593606
# 45                                    1-methylxanthine      0.0595718
# 558                                  sebacate (C10-DC)      0.0594121
# 703                              pyroglutamyltyrosine*     -0.0591546
# 122              3-(3-hydroxyphenyl)propionate sulfate      0.0572883
# 788                                    histidylleucine      0.0873989
# 371                      3-hydroxybutyrylcarnitine (1)      0.0563991
# 417                                         L-urobilin      0.0559314
# 157      androstenediol (3beta,17beta) monosulfate (2)      0.0559976
# 635                                             valine     -0.0568930
# 557                                    scyllo-inositol      0.0573366
# 823                                  N-acetylhistamine      0.0865821
# 618                                   tyrosylglutamate     -0.0573342
# 521                                 phenylalanylserine     -0.0582678
# 791                                    hyodeoxycholate      0.0858350
# 792                         ibuprofen acyl glucuronide      0.0854860
# 777                                   carboxyibuprofen      0.0854860
# 606                             trans-4-hydroxyproline      0.0557434
# 516                             phenylalanylisoleucine     -0.0778975
# 623                                     tyrosylleucine     -0.0568520
# 530                             pivaloylcarnitine (C5)     -0.0775276
# 327                                          glutamate     -0.0547226
# 773                            alpha-glutamylglutamate     -0.0836286
# 603                                     thymol sulfate      0.0535124
# 351                                       glycylvaline     -0.0548473
# 512                               phenylalanylarginine     -0.0524230
# 644                                    valyltryptophan     -0.0739479
# 617                                     tyrosylalanine     -0.0740513
# 455                                  N-acetylcarnosine      0.0521894
# 37                             1-linoleoyl-GPE (18:2)*      0.0521150
# 75                               2-aminophenol sulfate      0.0523187
# 92                                  2-hydroxyoctanoate      0.0520149
# 320                             gamma-glutamyltyrosine     -0.0520601
# 420                                       lysylleucine     -0.0536514
# 620                                     tyrosylglycine     -0.0543086
# 434                                       myo-inositol     -0.0524113
# 237                                    beta-tocopherol     -0.0532441
# 827                           Fibrinopeptide A (7-16)*     -0.0790449
# 596                                          threonate     -0.0513660
# 564                                      seryltyrosine     -0.0522080
# 386                                  isobutyrylglycine      0.0507800
# 387                                         isoleucine     -0.0507461
# 221                                     arginylproline     -0.0710914
# 408                                     leucyltyrosine     -0.0706809
# 416                        linoleoylcarnitine (C18:2)*     -0.0498806
# 335                               glycerol 3-phosphate      0.0489642
# 113                             2-stearoyl-GPE (18:0)*     -0.0490295
# 480                                  N-octanoylglycine      0.0505308
# 586                                       taurocholate     -0.0486813
# 409                                     leukotriene B4     -0.0682836
# 569                                        sphinganine      0.0478264
# 556                                          sarcosine      0.0491839
# 437                           myristoylcarnitine (C14)      0.0478092
# 727                  4-hydroxyphenylacetatoylcarnitine      0.0494021
# 490                            oleoylcarnitine (C18:1)     -0.0479973
# 647                                           xanthine     -0.0474803
# 834  5alpha-androstan-3alpha,17beta-diol 17-glucuro...     -0.2271684
# 101                   2-methylmalonylcarnitine (C4-DC)      0.0482405
# 193                                       acetoacetate      0.0468172
# 117                      3-(4-hydroxyphenyl)propionate     -0.0661443
# 542                                         pyridoxate      0.0465204
# 754                             3-hydroxyhexanoic acid      0.0475363
# 639                                     valylhistidine     -0.0471703
# 814         S-(3-hydroxypropyl)mercapturic acid (HPMA)      0.0698178
# 700                          dodecenedioate (C12:1-DC)      0.0614693
# 357                          hexadecanedioate (C16-DC)      0.0453636
# 248                                     caproate (6:0)      0.0454001
# 273                                     cyclo(leu-pro)      0.0450831
# 32                            1-eicosenoyl-GPC (20:1)*     -0.0451185
# 100                      2-methylbutyrylcarnitine (C5)     -0.0440115
# 504                                       penicillin G     -0.0594072
# 423                                      maltotetraose     -0.0620391
# 292                 docosapentaenoate (n6 DPA; 22:5n6)      0.0444936
# 319                           gamma-glutamyltryptophan     -0.0454717
# 439                 N1-Methyl-2-pyridone-5-carboxamide     -0.0441683
# 750                                         valine ion      0.0437213
# 223                                         asparagine      0.0437264
# 451                                   N-acetylarginine      0.0432836
# 554                                         salicylate     -0.0433664
# 589                        taurolithocholate 3-sulfate     -0.0430946
# 160                                 4-hydroxyhippurate     -0.0427390
# 611                                 tryptophan betaine     -0.0427377
# 664                        octadecenedioate (C18:1-DC)     -0.0424038
# 816                                         solanidine     -0.0647586
# 36                              1-linoleoyl-GPC (18:2)      0.0419019
# 173       5alpha-androstan-3beta,17beta-diol disulfate      0.0418894
# 325                                            glucose      0.0419106
# 768                    2-methoxyacetaminophen sulfate*      0.0603722
# 853                            alpha-ketoglutaramate**      0.2010788
# 430                                   methionylalanine      0.0586954
# 428                            margarate, methyl ester      0.0583896
# 125                               3-ethylphenylsulfate     -0.0410839
# 518                             phenylalanylmethionine     -0.0579883
# 226                                  asparaginylvaline     -0.0418734
# 393                                    isoleucylvaline      0.0400452
# 69                    21-hydroxypregnenolone disulfate     -0.0400533
# 817                                     thromboxane B2     -0.0611271
# 796                                isoleucylisoleucine      0.0609080
# 375                                          ibuprofen      0.0400596
# 594                                       theophylline      0.0388681
# 798                                    isoleucylserine      0.0595269
# 825                                pyroglutamyllysine*     -0.0596217
# 274                                     cyclo(phe-pro)      0.0390101
# 135                          3-methoxytyramine sulfate     -0.0389306
# 56                          1-palmitoleoyl-GPC (16:1)*     -0.0384429
# 716                                    eugenol sulfate      0.0379821
# 636                                       valylalanine     -0.0535516
# 53                                1-oleoyl-GPG (18:1)*     -0.0379246
# 608                 trigonelline (N'-methylnicotinate)     -0.0380035
# 842                                             folate      0.1851993
# 345                              glycoursodeoxycholate     -0.0379178
# 762                        1-methyl-4-imidazoleacetate     -0.0572191
# 25                       1-docosahexaenoyl-GPE (22:6)*      0.0372658
# 143                                  3-methylhistidine     -0.0373764
# 111                                     2-piperidinone      0.0357971
# 615                            tryptophylphenylalanine      0.0363339
# 561                                       serylleucine     -0.0374247
# 362                              histidylphenylalanine     -0.0365279
# 803                                   leucylisoleucine      0.0544363
# 329                                  glutaminylleucine     -0.0367796
# 33                         1-linolenoylglycerol (18:3)      0.0499198
# 772  5alpha-androstan-3beta,17beta-diol monosulfate...     -0.0551059
# 220                                           arginine      0.0367270
# 531                  pregnenediol sulfate (C21H34O5S)*      0.0364121
# 77                          2-arachidonoyl-GPE (20:4)*     -0.0354891
# 331                       glutathione, oxidized (GSSG)     -0.0499604
# 822                                  2-furoylcarnitine      0.0539641
# 299                                      ergothioneine      0.0366822
# 249                                    caprylate (8:0)      0.0352090
# 534                               pregnenolone sulfate      0.0359771
# 208                              alpha-hydroxycaproate     -0.0358331
# 500                           palmitoylcarnitine (C16)     -0.0343028
# 70              21-hydroxypregnenolone monosulfate (1)      0.0351328
# 334                               glycerol 2-phosphate     -0.0342153
# 235                                            betaine     -0.0343795
# 813                                            ribitol     -0.0531146
# 304                                       ethanolamine      0.0343404
# 593                                        theobromine      0.0342728
# 787                                 histidylisoleucine      0.0522812
# 426                                            mannose      0.0335435
# 300                                   erucate (22:1n9)      0.0475327
# 212                                   alpha-tocopherol     -0.0335438
# 688                                  suberoylcarnitine      0.0349628
# 246                                        campesterol     -0.0346075
# 767                2-methoxyacetaminophen glucuronide*     -0.0498045
# 577                                   suberate (C8-DC)     -0.0460946
# 826                                   leucylglutamine*      0.0499741
# 686                               beta-citrylglutamate     -0.0436027
# 555                           salicyluric glucuronide*      0.0324358
# 169               5-acetylamino-6-amino-3-methyluracil      0.0321801
# 570                                        sphingosine     -0.0319127
# 851                                            sucrose     -0.1538644
# 234                   beta-hydroxyisovaleroylcarnitine      0.0325792
# 820             glycochenodeoxycholate glucuronide (1)      0.0451377
# 560                                          serotonin      0.0321402
# 532                         pregnanediol-3-glucuronide      0.0309632
# 394                                 isovalerate (i5:0)      0.0309339
# 97                             2-linoleoyl-GPC (18:2)*      0.0305135
# 418                                             lysine     -0.0305937
# 763                         1-palmitoleoyl-GPE (16:1)*      0.0455720
# 584                             tauro-beta-muricholate      0.0297393
# 119          3-(N-acetyl-L-cystein-S-yl) acetaminophen      0.0293442
# 641                                 valylphenylalanine     -0.0300686
# 496                            palmitate, methyl ester     -0.0287767
# 793                                 isoleucylaspartate      0.0437283
# 215                                          arabinose     -0.0283137
# 227                                          aspartate     -0.0282720
# 139                             3-methyl-2-oxobutyrate     -0.0284784
# 255                                        cholesterol      0.0278789
# 832                             1-palmitoyl-GPA (16:0)      0.1354006
# 771  5alpha-androstan-3alpha,17beta-diol monosulfat...     -0.0422363
# 670                       hexadecenedioate (C16:1-DC)*     -0.0371518
# 795                                 isoleucylglutamine      0.0417006
# 572                                        stachydrine      0.0275155
# 342                                    glycohyocholate      0.0273417
# 162                            4-hydroxyphenylpyruvate     -0.0269510
# 379                                      indoleacetate      0.0247820
# 83                                    2-ethylhexanoate      0.0245212
# ...
# 806         0.0332195     0.9743680260444507     0.7713300984277597 0.9911616
# 524         0.0034182              0.9760332              0.9652444 0.9911616
# 243        -0.1153413              0.9757640              0.1401451 0.9911616
# 118        -0.1051498     0.9761089107317498     0.1857374338693134 0.9911616
# 389        -0.0211126     0.9785812804863561     0.7910166808462669 0.9924948
# 138         0.0622132     0.9827574954446734     0.4344912639674625 0.9939233
# 213        -0.0539825              0.9827130              0.4910446 0.9939233
# 219         0.0355674              0.9834732              0.6501589 0.9939233
# 669         0.0652814     0.9864855916159917    0.41212911463461366 0.9957921
# 245         0.0053970              0.9901678              0.9451492 0.9970003
# 438         0.0640146              0.9923414              0.4140032 0.9970003
# 550        -0.0007217              0.9921742              0.9926601 0.9970003
# 105         0.0724790              0.9921093              0.3548884 0.9970003
# 489         0.0754647              0.9969875              0.3353636 0.9971768
# 344         0.0707009              0.9958248              0.3668467 0.9971768
# 59          0.0544054              0.9971768              0.4876497 0.9971768
# 203        -0.0530842              0.9942540              0.4982962 0.9971768
#
#      q_matched
# 835  0.3162791
# 810  0.4160564
# 849  0.8116910
# 845  0.6560294
# 392  0.4033085
# 398  0.1255079
# 655  0.0774183
# 286  0.2281748
# 752  0.0774183
# 146  0.1790591
# 41   0.1381102
# 241  0.0490920
# 163  0.2009572
# 446  0.2723836
# 399  0.1381102
# 128  0.0490920
# 714  0.2262588
# 72   0.1243673
# 204  0.5279362
# 252  0.1149309
# 463  0.1703584
# 74   0.1243673
# 238  0.1703584
# 369  0.3162791
# 224  0.2723836
# 753  0.1327436
# 785  0.1703584
# 467  0.2850205
# 445  0.2723836
# 671  0.2009572
# 333  0.1164768
# 336  0.1951825
# 458  0.1381102
# 131  0.0774183
# 464  0.4528807
# 483  0.1244972
# 124  0.0774183
# 266  0.9943901
# 525  0.2245790
# 650  0.4719982
# 427  0.1149309
# 228  0.2894593
# 348  0.6581424
# 495  0.1372361
# 757  0.1568920
# 681  0.0774183
# 651  0.5049649
# 10   0.2268618
# 462  0.1703441
# 132  0.1951825
# 425  0.1703584
# 313  0.7835368
# 279  0.3334641
# 413  0.1244972
# 563  0.4645822
# 48   0.6546680
# 323  0.9227615
# 106  0.7337007
# 604  0.8116910
# 705  0.8247014
# 251  0.9512255
# 756  0.8011659
# 112  0.9943901
# 806  0.9479266
# 524  0.9943901
# 243  0.5279393
# 118  0.5910455
# 389  0.9479266
# 138  0.8116910
# 213  0.8378168
# 219  0.9043735
# 669  0.8011659
# 245  0.9943901
# 438  0.8011659
# 550  0.9961512
# 105  0.7749604
# 489  0.7614622
# 344  0.7830941
# 59   0.8378168
# 203  0.8446368

# %%
display(sig_corr_matched)
# Out:
#                   metab  Spearman_bulk  Spearman_matched    p_bulk p_matched  \
# 128  3-hydroxydecanoate      0.2417024         0.2957829 0.0010455 0.0001147
# 241          biliverdin      0.2547611         0.3077873 0.0005382 0.0000578
#
#        q_bulk  q_matched
# 128 0.0559349  0.0490920
# 241 0.0383896  0.0490920

# %%
hmdb_ids = convertHMDB(corr_df['metab'].values, chem_df)
corr_df['hmdb'] = hmdb_ids

metab_ids = [chem_df.loc[i, 'id'] if pd.isnull(id) else id for i, id in enumerate(hmdb_ids)]
corr_df['metab_ids'] = metab_ids

corr_df = corr_df.drop_duplicates(subset='hmdb')
corr_df = corr_df.sort_values(by='p_bulk')
corr_df = corr_df.reset_index(drop=True)
corr_df.to_csv('./tmod_corr.txt', sep='\t')

# %%
#WHAT'S THE SIGNAL TO NOISE RATIO?
#Within same individual, how does the metabolite change over time? (Means of std. dev, Pearson correlation)
#Identifying highly variable metabolites
#Pearson correlation between individuals in the same "case-control" match

all_ctrl = full_df[full_df['group'].str.contains('control')]

for (donor), group in all_ctrl.groupby('donor_id'):
    shared_features = group[features].dropna(axis=1).T #drop columns that are not shared
    
    if (shared_features.shape[1] > 1):
        corr_temp, sig_temp = sp.stats.pearsonr(shared_features.values[1:, 0], shared_features.values[1:, 1])
        display(corr_temp)

# %%
#CRASHES MY NOTEBOOK WHEN I GO BY DONOR LOL CRYING
#metab_var = all_ctrl.groupby('donor_id').apply(lambda x: np.std(x) / np.mean(x))
#display(metab_var)

# %%
weights = pd.read_csv('Weights.csv')
print(list(weights))
weights = weights.rename({list(weights)[0] : 'metab_ids'}, axis='columns')
hmdb_ids = convertHMDB(weights['metab_ids'].values, chem_df)
weights['hmdb'] = hmdb_ids

metab_ids = [chem_df.loc[i, 'id'] if pd.isnull(id) else id for i, id in enumerate(hmdb_ids)]
weights['metab_ids'] = metab_ids
weights.head()

weights.to_csv('./Weights_HMDB.csv')
# Out:
# ['Unnamed: 0', '0']

# %%
def SVM_pred(data, features):
#Support vector machine
#classify  case vs. controls (vanilla version)
# ways to improve:
# i) Hyperparmeter serach ii) feature selection (serach for best threshold value) iii) test models
# using different time points (currently just takes all case and control data) iv) qualitative data?
# v) how much data do we need in train vs. test (+validation)

    # finding assigning labels to control (0) and case (1) subjects
    caseControlLabels = []
    for case_control in data['group']:
        if case_control == 'control':
            caseControlLabels.append(0)
        else:
            caseControlLabels.append(1)

    # extracting metabolite names -- these will be the features
    metabolites = []
    for feat in features:
        if 'M.' in feat:
            metabolites.append(feat)

    # data matrix will only consist of metabolite features (excluding other qualitative data)
    # dropping rows with nan
    fullSVM_df = data.loc[:,metabolites[0]:metabolites[-1]].dropna(axis=1)

    X_train, X_test, y_train, y_test = train_test_split(fullSVM_df, caseControlLabels, test_size=0.33, random_state=42)

    # hinge loss for linear SVM; L1 for sparsity; don't shuffle data each epoch; don't bias classes; # fairly strong bias for L1
    clf = linear_model.SGDClassifier(loss="hinge", penalty="l1", shuffle=False, class_weight="balanced" , alpha=0.001)
    featSelection = SelectFromModel(clf, threshold=0.01) # threshold for feature selection 
    model = Pipeline([
                      ('fs', featSelection), 
                      ('clf', clf), 
                    ])
    model.fit(X_train, y_train)# train model
    
    # feature weightings
    SVMFeat_df = pd.DataFrame([model.named_steps["clf"].coef_[0]], 
                                    columns=fullSVM_df.columns[model.named_steps["fs"].get_support()])
    # calculating model accurarcy
    modelAccuracy = model.score(X_test, y_test)
    
    # ROC calculation
    y_score = model.predict(X_test)
    y_score = model.decision_function(X_test)
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)

    # plotting ROC
    lw = 2
    plt.figure(dpi=400, figsize=(3,3))
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('SVM ROC')
    plt.legend(loc="lower right")
    plt.show()

    # precision recall
    plt.figure(dpi=400, figsize=(3,3))
    averagePrecision = average_precision_score(y_test, y_score)
    precision, recall, _ = precision_recall_curve(y_test, y_score)
    step_kwargs = ({'step': 'post'}
                   if 'step' in signature(plt.fill_between).parameters
                   else {})
    plt.step(recall, precision, color='b', alpha=0.2,
             where='post')
    plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall curve: AP={0:0.2f}'.format(
              averagePrecision))

# %%
def SVM_pred_v2(data, features, alpha=0.001, threshold=0.01, plot = True, kernel = 'linear'):
#Support vector machine
#classify  case vs. controls (vanilla version)
# ways to improve:
# i) Hyperparmeter serach ii) feature selection (serach for best threshold value) iii) test models
# using different time points (currently just takes all casedand control data) iv) qualitative data?
# v) how much data do we need in train vs. test (+validation)

    # assigning labels to control (0) and case (1) subjects
    caseControlLabels = [0 if label == 'control' else 1 for label in data['group']]

    # extracting metabolite names --- these will be the features
    metabolites = features[1:]

    # data matrix will only consist of metabolite features (excluding other qualitative data)
    # dropping rows with nan
    fullSVM_df = data.loc[:,metabolites[0]:metabolites[-1]].dropna(axis=1)

    X_train, X_test, y_train, y_test = train_test_split(fullSVM_df, caseControlLabels, test_size=0.33, random_state=42)

    if kernel == 'linear':
        # hinge loss for linear SVM; L1 for sparsity; don't shuffle data each epoch; don't bias classes; # fairly strong bias for L1
        clf = linear_model.SGDClassifier(loss='hinge', penalty='l1', shuffle=False, class_weight='balanced' , alpha=alpha)
        featSelection = SelectFromModel(clf, threshold=threshold) # threshold for feature selection 
        model = Pipeline([
                          ('fs', featSelection), 
                          ('clf', clf), 
                        ])
        model.fit(X_train, y_train)# train model

        # feature weightings
        SVMFeat_df = pd.DataFrame([model.named_steps['clf'].coef_[0]], 
                                  columns=fullSVM_df.columns[model.named_steps['fs'].get_support()])
        # calculating model accurarcy
        modelAccuracy = model.score(X_test, y_test)
        cv = min(caseControlLabels.count(0), caseControlLabels.count(0))
        scores = cross_val_score(clf, fullSVM_df, caseControlLabels, cv=cv)
        mean_cv = np.mean(scores) * 100
        print('The average CV score was:', mean_cv)
    elif kernel == 'rbf' or kernel == 'sigmoid':
        clf = svm.SVC(kernel=kernel, C = 10.0, gamma=0.1)
        param_grid = {'C': [0.0001, 0.001, 0.1, 1, 10, 100,1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.00001, 10,100]}

        # Make grid search classifier
        model = GridSearchCV(svm.SVC(), param_grid, verbose=1)

        model.fit(X_train, y_train)# train model
        modelAccuracy = model.score(X_test, y_test) 
        cv = min(caseControlLabels.count(0), caseControlLabels.count(0))
        scores = cross_val_score(clf_grid, fullSVM_df, caseControlLabels, cv=3)
        mean_cv = np.mean(scores) * 100
        print('The average CV score was:', mean_cv)
        print('The model accuracy was:', modelAccuracy)

    if plot == True:
        # ROC calculation
        y_score = model.predict(X_test)
        y_score = model.decision_function(X_test)
        fpr, tpr, _ = roc_curve(y_test, y_score)
        roc_auc = auc(fpr, tpr)


        # plotting ROC
        lw = 2
        plt.figure(dpi=400, figsize=(3,3))
        plt.plot(fpr, tpr, color='darkorange',
                 lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
        plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('SVM ROC')
        plt.legend(loc='lower right')
        plt.show()

        # precision recall
        plt.figure(dpi=400, figsize=(3,3))
        averagePrecision = average_precision_score(y_test, y_score)
        precision, recall, _ = precision_recall_curve(y_test, y_score)
        step_kwargs = ({'step': 'post'}
                       if 'step' in signature(plt.fill_between).parameters
                       else {})
        plt.step(recall, precision, color='b', alpha=0.2,
                 where='post')
        plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.0])
        plt.title('Precision-Recall curve: AP={0:0.2f}'.format(
                  averagePrecision))
    return modelAccuracy, mean_cv

# %%
def SVM_pred_v3(data, features, alpha=0.001, plot = True, kernel = 'linear'):
#Support vector machine
#classify  case vs. controls (vanilla version) -- done
# ways to improve:
# i) Hyperparmeter serach -- done ii) feature selection (serach for best threshold value) -- done iii) test models
# using different time points (currently just takes all casedand control data) iv) qualitative data?
# v) how much data do we need in train vs. test (+validation)

    # assigning labels to control (0) and case (1) subjects
    caseControlLabels = [0 if label == 'control' else 1 for label in data['group']]

    # extracting metabolite names --- these will be the features
    metabolites = features[1:]

    # data matrix will only consist of metabolite features (excluding other qualitative data)
    # dropping columns (features) with nan values -- most of these don't have enough info to impute
    fullSVM_df = data.loc[:,metabolites[0]:metabolites[-1]].dropna(axis=1)

    # splitting into training (80%) and testing sets (20%) -- cross validation will be used
    X_train, X_test, y_train, y_test = train_test_split(fullSVM_df, caseControlLabels, test_size=0.20, random_state=42)

    # running SVM
    threshold=0.01
    
    if kernel == 'linear':
        
        ### ------- Everything in this block is for the hyperparameter sweep ------- ###
        
        # cross validation for parameter sweeps
        cv = RepeatedStratifiedKFold(n_splits=10,n_repeats=3, random_state=42)
        
        # hinge loss for linear SVM; L1 for sparsity; don't shuffle data each epoch (reproducibility); 
        # balanced = don't bias classe (class imbalance) s;  best alpha found through parameter sweep -- manually 
        # setting in order to prevent long run time
        clf = linear_model.SGDClassifier(loss='hinge', penalty='l1', shuffle=False, class_weight='balanced' , alpha=alpha)
        
        # thresholding for feature selection
        featSelection = SelectFromModel(clf, threshold=threshold) # threshold for feature selection 
        
        # pipeline for SVM model -- this is still for cross-validation
        model = Pipeline([
                          ('fs', featSelection), 
                          ('clf', clf), 
                        ])
        # range of threshold values to test
        params = {'fs__threshold': np.linspace(0.001, 15, num=25)} # clf__alpha': np.logspace(-5, -3, num=3)

        # performing grid search
        grid = GridSearchCV(model, params, cv=cv)
        
        # fitting model
        grid.fit(fullSVM_df, caseControlLabels)
        CVscore = grid.best_score_
        print("The best parameters are %s with a score of %0.2f"% (grid.best_params_, CVscore))
        
        ### ------- End hyperparameter sweep ------- ###
        
        ### ------- Running SVM model after hyperparameter sweep ------- ###
        # arguments same as above for the same reasons
        clf = linear_model.SGDClassifier(loss='hinge', penalty='l1', shuffle=False, class_weight='balanced' , alpha=alpha)
        featSelection = SelectFromModel(clf, threshold=grid.best_params_['fs__threshold']) # threshold for feature selection 
        model = Pipeline([
                          ('fs', featSelection), 
                          ('clf', clf), 
                        ])
        model.fit(X_train, y_train)# train model
#         sorted(pipeline.get_params().keys())

        SVMFeat_df = pd.DataFrame([model.named_steps['clf'].coef_[0]], 
                                  columns=fullSVM_df.columns[model.named_steps['fs'].get_support()])
        # calculating model accurarcy
        modelAccuracy = model.score(X_test, y_test)
        print('The accuracy was:', modelAccuracy)

    elif kernel == 'rbf' or kernel == 'sigmoid':
        
        # setting up non-linear model (either radial basis function or sigmoid)
        clf = svm.SVC(kernel=kernel, C = 10.0, gamma=0.1)
        
        # setting up grid for hyperparameter search
        param_grid = {'C': [0.0001, 0.001, 0.1, 1, 10, 100,1000], 'gamma': [0.00001, 0.001, 0.01, 0.1, 1, 10, 100]}

        # make grid search classifier (does hyperparameter sweep and cross-validates )
        model = GridSearchCV(clf, param_grid, verbose=1) # clf svm.SVC()

        # fitting and testing model
        model.fit(X_train, y_train)# train model
        modelAccuracy = model.score(X_test, y_test) 
#         cv = min(caseControlLabels.count(0), caseControlLabels.count(0))
#         scores = cross_val_score(model, fullSVM_df, caseControlLabels, cv=3)
#         mean_cv = np.mean(scores) * 100
        SVMFeat_df = []
        CVscore = model.best_score_
        print('The average CV score was:', CVscore)
        print('The model accuracy was:', modelAccuracy)

    if plot == True:
        # ROC calculation
        y_score = model.predict(X_test)
        y_score = model.decision_function(X_test)
        fpr, tpr, _ = roc_curve(y_test, y_score)
        roc_auc = auc(fpr, tpr)


        # plotting ROC
        lw = 2
        plt.figure(dpi=400, figsize=(3,3))
        plt.plot(fpr, tpr, color='darkorange',lw=lw) #, label='ROC curve (area = %0.2f)' % roc_auc
        plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('SVM ROC')
        plt.legend(loc='lower right')
        plt.savefig('ROC' + kernel + '.pdf')
        plt.show()


        # precision recall
        plt.figure(dpi=400, figsize=(3,3))
        averagePrecision = average_precision_score(y_test, y_score)
        precision, recall, _ = precision_recall_curve(y_test, y_score)
        step_kwargs = ({'step': 'post'}
                       if 'step' in signature(plt.fill_between).parameters
                       else {})
        plt.step(recall, precision, color='b', alpha=0.2,
                 where='post')
        plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.0])
        plt.title('Precision-Recall curve: AP={0:0.2f}'.format(
                  averagePrecision))
        plt.savefig('PRC' + kernel + '.pdf')

    return modelAccuracy, CVscore, SVMFeat_df

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_recall_curve
from sklearn.utils.fixes import signature
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn import svm

fullData_SVM_dict = {'Linear Full Model': ['linear'], 
                     'RBF Full Model': ['rbf']}
# order will be [modelAccuracy, CVscore, SVMFeat_df]

for model_type, kernel_type in fullData_SVM_dict.items():
    accuracy, CVmeanScore, FeatureSelection  = SVM_pred_v3(full_df, features, alpha=0.001, 
                                                           plot = True, kernel = kernel_type[0])
    fullData_SVM_dict[model_type].append([accuracy, CVmeanScore, FeatureSelection])

# %%
fullData_SVM_dict = {'Linear Full Model': ['linear'], 
                     'RBF Full Model': ['rbf']}

for thing, key in fullData_SVM_dict.items():
    print(thing)
    print(key)

# %%
fullData_SVM_dict['Linear Full Model'][1][2].shape

# %%
# metabolites = features[1:]
sites = ['AHRI', 'MRC', 'SUN', 'MAK']

AHRI_df = full_df[full_df['site.gr'].str.startswith(sites[0])]
MRC_df = full_df[full_df['site.gr'].str.startswith(sites[1])]
SUN_df = full_df[full_df['site.gr'].str.startswith(sites[2])]
MAK_df = full_df[full_df['site.gr'].str.startswith(sites[3])]

acc = SVM_pred_v3(MAK_df, features, alpha=0.001, threshold=0.01, plot = True, kernel = 'rbf')

# # data matrix will only consist of metabolite features (excluding other qualitative data)
# # dropping rows with nan
# fullSVM_df = data.loc[:,metabolites[0]:metabolites[-1]].dropna(axis=1)

# %%
acc = SVM_pred_v3(MRC_df, features, alpha=0.001, threshold=0.01, plot = True, kernel = 'rbf')

# %%
acc = SVM_pred_v3(SUN_df, features, alpha=0.001, threshold=0.01, plot = True, kernel = 'rbf')

# %%
acc = SVM_pred_v3(MAK_df, features, alpha=0.001, threshold=0.01, plot = True, kernel = 'rbf')

# %%
set(full_df['time_to_tb'])

# %%
df = pd.read_csv('biochemicals_full_list_5.csv')
missingHMDB = []
for index, row in df.iterrows():
    if str(row['HMDB']) == 'nan' and row['BIOCHEMICAL'][0:3] != 'X -':
        missingHMDB.append(row['BIOCHEMICAL'])

# %%
df = pd.read_csv('biochemicals_full_list_5.csv')
missingHMDB = []
for index, row in df.iterrows():
    if str(row['HMDB']) == 'nan' and row['BIOCHEMICAL'][0:3] != 'X -':
        missingHMDB.append(row['BIOCHEMICAL'])

# %%
my_df = pd.DataFrame(missingHMDB)
my_df = my_df[~my_df[0].str.startswith('X -')]
my_df.to_csv('out.csv', index=False, header=False)
